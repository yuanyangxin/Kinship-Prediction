# %%
# import necessary modules we need, all these code running on Kaggle online notebooks, which offers us free GPU
import numpy as np 
import pandas as pd 
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/sample_submission.csv
# /kaggle/input/train_relationships.csv
# /kaggle/input/test/face00857.jpg
# /kaggle/input/test/face01342.jpg
# /kaggle/input/test/face02898.jpg
# /kaggle/input/test/face02732.jpg
# /kaggle/input/test/face05963.jpg
# /kaggle/input/test/face00353.jpg
# /kaggle/input/test/face06083.jpg
# /kaggle/input/test/face01782.jpg
# /kaggle/input/test/face01938.jpg
# /kaggle/input/test/face04963.jpg
# /kaggle/input/test/face00383.jpg
# /kaggle/input/test/face02668.jpg
# /kaggle/input/test/face04394.jpg
# /kaggle/input/test/face01741.jpg
# /kaggle/input/test/face01621.jpg
# /kaggle/input/test/face05207.jpg
# /kaggle/input/test/face04239.jpg
# /kaggle/input/test/face06171.jpg
# /kaggle/input/test/face05276.jpg
# /kaggle/input/test/face00767.jpg
# /kaggle/input/test/face01474.jpg
# /kaggle/input/test/face02813.jpg
# /kaggle/input/test/face01751.jpg
# /kaggle/input/test/face05902.jpg
# /kaggle/input/test/face03187.jpg
# /kaggle/input/test/face01201.jpg
# /kaggle/input/test/face05790.jpg
# /kaggle/input/test/face03997.jpg
# /kaggle/input/test/face05226.jpg
# /kaggle/input/test/face00876.jpg
# /kaggle/input/test/face02395.jpg
# /kaggle/input/test/face00438.jpg
# /kaggle/input/test/face06186.jpg
# /kaggle/input/test/face00564.jpg
# /kaggle/input/test/face02228.jpg
# /kaggle/input/test/face04056.jpg
# /kaggle/input/test/face03986.jpg
# /kaggle/input/test/face05950.jpg
# /kaggle/input/test/face00263.jpg
# /kaggle/input/test/face02501.jpg
# /kaggle/input/test/face05620.jpg
# /kaggle/input/test/face03979.jpg
# /kaggle/input/test/face00848.jpg
# /kaggle/input/test/face01689.jpg
# /kaggle/input/test/face05995.jpg
# /kaggle/input/test/face05737.jpg
# /kaggle/input/test/face04765.jpg
# /kaggle/input/test/face01162.jpg
# /kaggle/input/test/face00904.jpg
# /kaggle/input/test/face02220.jpg
# /kaggle/input/test/face02774.jpg
# /kaggle/input/test/face05134.jpg
# /kaggle/input/test/face06227.jpg
# /kaggle/input/test/face02766.jpg
# /kaggle/input/test/face01670.jpg
# /kaggle/input/test/face01006.jpg
# /kaggle/input/test/face05456.jpg
# /kaggle/input/test/face03352.jpg
# /kaggle/input/test/face03829.jpg
# /kaggle/input/test/face05973.jpg
# /kaggle/input/test/face03799.jpg
# /kaggle/input/test/face02215.jpg
# /kaggle/input/test/face04066.jpg
# /kaggle/input/test/face03888.jpg
# /kaggle/input/test/face04135.jpg
# /kaggle/input/test/face03808.jpg
# /kaggle/input/test/face04780.jpg
# /kaggle/input/test/face01417.jpg
# /kaggle/input/test/face01448.jpg
# /kaggle/input/test/face01838.jpg
# /kaggle/input/test/face03547.jpg
# /kaggle/input/test/face02043.jpg
# /kaggle/input/test/face04463.jpg
# /kaggle/input/test/face03063.jpg
# /kaggle/input/test/face03001.jpg
# /kaggle/input/test/face04054.jpg
# /kaggle/input/test/face02094.jpg
# /kaggle/input/test/face01283.jpg
# /kaggle/input/test/face01003.jpg
# /kaggle/input/test/face05475.jpg
# /kaggle/input/test/face01805.jpg
# /kaggle/input/test/face06243.jpg
# /kaggle/input/test/face05334.jpg
# /kaggle/input/test/face05570.jpg
# /kaggle/input/test/face02712.jpg
# /kaggle/input/test/face01799.jpg
# /kaggle/input/test/face00207.jpg
# /kaggle/input/test/face02529.jpg
# /kaggle/input/test/face01871.jpg
# /kaggle/input/test/face02111.jpg
# /kaggle/input/test/face00350.jpg
# /kaggle/input/test/face05853.jpg
# /kaggle/input/test/face03459.jpg
# /kaggle/input/test/face01665.jpg
# /kaggle/input/test/face00772.jpg
# /kaggle/input/test/face02231.jpg
# /kaggle/input/test/face03275.jpg
# /kaggle/input/test/face04084.jpg
# /kaggle/input/test/face02297.jpg
# /kaggle/input/test/face05562.jpg
# /kaggle/input/test/face01225.jpg
# /kaggle/input/test/face00097.jpg
# /kaggle/input/test/face04503.jpg
# /kaggle/input/test/face01939.jpg
# /kaggle/input/test/face05813.jpg
# /kaggle/input/test/face06168.jpg
# /kaggle/input/test/face02444.jpg
# /kaggle/input/test/face03132.jpg
# /kaggle/input/test/face00150.jpg
# /kaggle/input/test/face00987.jpg
# /kaggle/input/test/face02767.jpg
# /kaggle/input/test/face02100.jpg
# /kaggle/input/test/face05310.jpg
# /kaggle/input/test/face04687.jpg
# /kaggle/input/test/face02225.jpg
# /kaggle/input/test/face04951.jpg
# /kaggle/input/test/face00999.jpg
# /kaggle/input/test/face05951.jpg
# /kaggle/input/test/face00583.jpg
# /kaggle/input/test/face05164.jpg
# /kaggle/input/test/face03122.jpg
# /kaggle/input/test/face03515.jpg
# /kaggle/input/test/face00028.jpg
# /kaggle/input/test/face03845.jpg
# /kaggle/input/test/face02443.jpg
# /kaggle/input/test/face04197.jpg
# /kaggle/input/test/face00309.jpg
# /kaggle/input/test/face00037.jpg
# /kaggle/input/test/face03323.jpg
# /kaggle/input/test/face06107.jpg
# /kaggle/input/test/face04905.jpg
# /kaggle/input/test/face05924.jpg
# /kaggle/input/test/face01604.jpg
# /kaggle/input/test/face02062.jpg
# /kaggle/input/test/face01254.jpg
# /kaggle/input/test/face01987.jpg
# /kaggle/input/test/face00723.jpg
# /kaggle/input/test/face05732.jpg
# /kaggle/input/test/face00902.jpg
# /kaggle/input/test/face02899.jpg
# /kaggle/input/test/face04074.jpg
# /kaggle/input/test/face02243.jpg
# /kaggle/input/test/face02129.jpg
# /kaggle/input/test/face99999.jpg
# /kaggle/input/test/face03809.jpg
# /kaggle/input/test/face02203.jpg
# /kaggle/input/test/face01864.jpg
# /kaggle/input/test/face00818.jpg
# /kaggle/input/test/face01301.jpg
# /kaggle/input/test/face03614.jpg
# /kaggle/input/test/face00297.jpg
# /kaggle/input/test/face01218.jpg
# /kaggle/input/test/face04204.jpg
# /kaggle/input/test/face04663.jpg
# /kaggle/input/test/face05840.jpg
# /kaggle/input/test/face01165.jpg
# /kaggle/input/test/face02278.jpg
# /kaggle/input/test/face03795.jpg
# /kaggle/input/test/face02516.jpg
# /kaggle/input/test/face01170.jpg
# /kaggle/input/test/face04078.jpg
# /kaggle/input/test/face02517.jpg
# /kaggle/input/test/face06124.jpg
# /kaggle/input/test/face00584.jpg
# /kaggle/input/test/face05162.jpg
# /kaggle/input/test/face05352.jpg
# /kaggle/input/test/face03366.jpg
# /kaggle/input/test/face05396.jpg
# /kaggle/input/test/face01279.jpg
# /kaggle/input/test/face00817.jpg
# /kaggle/input/test/face02821.jpg
# /kaggle/input/test/face03199.jpg
# /kaggle/input/test/face00055.jpg
# /kaggle/input/test/face03277.jpg
# /kaggle/input/test/face06078.jpg
# /kaggle/input/test/face02008.jpg
# /kaggle/input/test/face03733.jpg
# /kaggle/input/test/face00766.jpg
# /kaggle/input/test/face03131.jpg
# /kaggle/input/test/face00892.jpg
# /kaggle/input/test/face04537.jpg
# /kaggle/input/test/face02025.jpg
# /kaggle/input/test/face01887.jpg
# /kaggle/input/test/face00582.jpg
# /kaggle/input/test/face00423.jpg
# /kaggle/input/test/face02615.jpg
# /kaggle/input/test/face05640.jpg
# /kaggle/input/test/face04140.jpg
# /kaggle/input/test/face02191.jpg
# /kaggle/input/test/face01541.jpg
# /kaggle/input/test/face04890.jpg
# /kaggle/input/test/face01537.jpg
# /kaggle/input/test/face03637.jpg
# /kaggle/input/test/face02607.jpg
# /kaggle/input/test/face01519.jpg
# /kaggle/input/test/face02773.jpg
# /kaggle/input/test/face03743.jpg
# /kaggle/input/test/face02287.jpg
# /kaggle/input/test/face05375.jpg
# /kaggle/input/test/face05078.jpg
# /kaggle/input/test/face00295.jpg
# /kaggle/input/test/face01728.jpg
# /kaggle/input/test/face05655.jpg
# /kaggle/input/test/face01031.jpg
# /kaggle/input/test/face04736.jpg
# /kaggle/input/test/face05733.jpg
# /kaggle/input/test/face03589.jpg
# /kaggle/input/test/face00867.jpg
# /kaggle/input/test/face03849.jpg
# /kaggle/input/test/face01149.jpg
# /kaggle/input/test/face01650.jpg
# /kaggle/input/test/face02680.jpg
# /kaggle/input/test/face02362.jpg
# /kaggle/input/test/face03807.jpg
# /kaggle/input/test/face06092.jpg
# /kaggle/input/test/face03881.jpg
# /kaggle/input/test/face04637.jpg
# /kaggle/input/test/face04713.jpg
# /kaggle/input/test/face03844.jpg
# /kaggle/input/test/face04258.jpg
# /kaggle/input/test/face05457.jpg
# /kaggle/input/test/face00004.jpg
# /kaggle/input/test/face03562.jpg
# /kaggle/input/test/face02636.jpg
# /kaggle/input/test/face06026.jpg
# /kaggle/input/test/face02750.jpg
# /kaggle/input/test/face03234.jpg
# /kaggle/input/test/face02741.jpg
# /kaggle/input/test/face06153.jpg
# /kaggle/input/test/face05239.jpg
# /kaggle/input/test/face00092.jpg
# /kaggle/input/test/face02029.jpg
# /kaggle/input/test/face03305.jpg
# /kaggle/input/test/face00669.jpg
# /kaggle/input/test/face02628.jpg
# /kaggle/input/test/face02077.jpg
# /kaggle/input/test/face05065.jpg
# /kaggle/input/test/face00933.jpg
# /kaggle/input/test/face01056.jpg
# /kaggle/input/test/face02689.jpg
# /kaggle/input/test/face00829.jpg
# /kaggle/input/test/face05983.jpg
# /kaggle/input/test/face03369.jpg
# /kaggle/input/test/face01674.jpg
# /kaggle/input/test/face04437.jpg
# /kaggle/input/test/face01171.jpg
# /kaggle/input/test/face00405.jpg
# /kaggle/input/test/face05255.jpg
# /kaggle/input/test/face06160.jpg
# /kaggle/input/test/face05783.jpg
# /kaggle/input/test/face02601.jpg
# /kaggle/input/test/face05715.jpg
# /kaggle/input/test/face04030.jpg
# /kaggle/input/test/face06073.jpg
# /kaggle/input/test/face03311.jpg
# /kaggle/input/test/face03146.jpg
# /kaggle/input/test/face04059.jpg
# /kaggle/input/test/face04133.jpg
# /kaggle/input/test/face02159.jpg
# /kaggle/input/test/face05129.jpg
# /kaggle/input/test/face00656.jpg
# /kaggle/input/test/face05976.jpg
# /kaggle/input/test/face05020.jpg
# /kaggle/input/test/face05208.jpg
# /kaggle/input/test/face02953.jpg
# /kaggle/input/test/face05265.jpg
# /kaggle/input/test/face04812.jpg
# /kaggle/input/test/face05696.jpg
# /kaggle/input/test/face00404.jpg
# /kaggle/input/test/face05994.jpg
# /kaggle/input/test/face01678.jpg
# /kaggle/input/test/face02970.jpg
# /kaggle/input/test/face00659.jpg
# /kaggle/input/test/face02448.jpg
# /kaggle/input/test/face01496.jpg
# /kaggle/input/test/face03038.jpg
# /kaggle/input/test/face03876.jpg
# /kaggle/input/test/face00421.jpg
# /kaggle/input/test/face03724.jpg
# /kaggle/input/test/face06148.jpg
# /kaggle/input/test/face06237.jpg
# /kaggle/input/test/face00722.jpg
# /kaggle/input/test/face00363.jpg
# /kaggle/input/test/face03933.jpg
# /kaggle/input/test/face04347.jpg
# /kaggle/input/test/face06254.jpg
# /kaggle/input/test/face01466.jpg
# /kaggle/input/test/face02378.jpg
# /kaggle/input/test/face01539.jpg
# /kaggle/input/test/face04648.jpg
# /kaggle/input/test/face01193.jpg
# /kaggle/input/test/face01676.jpg
# /kaggle/input/test/face00193.jpg
# /kaggle/input/test/face02577.jpg
# /kaggle/input/test/face03079.jpg
# /kaggle/input/test/face02413.jpg
# /kaggle/input/test/face04172.jpg
# /kaggle/input/test/face01508.jpg
# /kaggle/input/test/face03264.jpg
# /kaggle/input/test/face04620.jpg
# /kaggle/input/test/face03422.jpg
# /kaggle/input/test/face00642.jpg
# /kaggle/input/test/face03089.jpg
# /kaggle/input/test/face03879.jpg
# /kaggle/input/test/face01821.jpg
# /kaggle/input/test/face01238.jpg
# /kaggle/input/test/face03413.jpg
# /kaggle/input/test/face05809.jpg
# /kaggle/input/test/face04041.jpg
# /kaggle/input/test/face05506.jpg
# /kaggle/input/test/face01091.jpg
# /kaggle/input/test/face03441.jpg
# /kaggle/input/test/face03500.jpg
# /kaggle/input/test/face05788.jpg
# /kaggle/input/test/face04222.jpg
# /kaggle/input/test/face00709.jpg
# /kaggle/input/test/face04822.jpg
# /kaggle/input/test/face04874.jpg
# /kaggle/input/test/face01219.jpg
# /kaggle/input/test/face04325.jpg
# /kaggle/input/test/face01920.jpg
# /kaggle/input/test/face05229.jpg
# /kaggle/input/test/face05279.jpg
# /kaggle/input/test/face00654.jpg
# /kaggle/input/test/face00073.jpg
# /kaggle/input/test/face02493.jpg
# /kaggle/input/test/face02637.jpg
# /kaggle/input/test/face05855.jpg
# /kaggle/input/test/face01128.jpg
# /kaggle/input/test/face02717.jpg
# /kaggle/input/test/face04907.jpg
# /kaggle/input/test/face02871.jpg
# /kaggle/input/test/face00066.jpg
# /kaggle/input/test/face01009.jpg
# /kaggle/input/test/face06253.jpg
# /kaggle/input/test/face00575.jpg
# /kaggle/input/test/face01917.jpg
# /kaggle/input/test/face04151.jpg
# /kaggle/input/test/face01482.jpg
# /kaggle/input/test/face03384.jpg
# /kaggle/input/test/face05545.jpg
# /kaggle/input/test/face03112.jpg
# /kaggle/input/test/face02350.jpg
# /kaggle/input/test/face00043.jpg
# /kaggle/input/test/face05676.jpg
# /kaggle/input/test/face05252.jpg
# /kaggle/input/test/face05391.jpg
# /kaggle/input/test/face04428.jpg
# /kaggle/input/test/face05947.jpg
# /kaggle/input/test/face02844.jpg
# /kaggle/input/test/face00445.jpg
# /kaggle/input/test/face06150.jpg
# /kaggle/input/test/face02920.jpg
# /kaggle/input/test/face04444.jpg
# /kaggle/input/test/face00694.jpg
# /kaggle/input/test/face01331.jpg
# /kaggle/input/test/face00877.jpg
# /kaggle/input/test/face04971.jpg
# /kaggle/input/test/face06175.jpg
# /kaggle/input/test/face01869.jpg
# /kaggle/input/test/face03310.jpg
# /kaggle/input/test/face04120.jpg
# /kaggle/input/test/face02108.jpg
# /kaggle/input/test/face05186.jpg
# /kaggle/input/test/face02865.jpg
# /kaggle/input/test/face03819.jpg
# /kaggle/input/test/face04685.jpg
# /kaggle/input/test/face04141.jpg
# /kaggle/input/test/face04268.jpg
# /kaggle/input/test/face02016.jpg
# /kaggle/input/test/face01344.jpg
# /kaggle/input/test/face00173.jpg
# /kaggle/input/test/face03127.jpg
# /kaggle/input/test/face04694.jpg
# /kaggle/input/test/face02103.jpg
# /kaggle/input/test/face01403.jpg
# /kaggle/input/test/face01100.jpg
# /kaggle/input/test/face06185.jpg
# /kaggle/input/test/face04613.jpg
# /kaggle/input/test/face01396.jpg
# /kaggle/input/test/face02262.jpg
# /kaggle/input/test/face05414.jpg
# /kaggle/input/test/face05517.jpg
# /kaggle/input/test/face01599.jpg
# /kaggle/input/test/face05516.jpg
# /kaggle/input/test/face04493.jpg
# /kaggle/input/test/face05111.jpg
# /kaggle/input/test/face01603.jpg
# /kaggle/input/test/face04416.jpg
# /kaggle/input/test/face03764.jpg
# /kaggle/input/test/face00458.jpg
# /kaggle/input/test/face02422.jpg
# /kaggle/input/test/face04417.jpg
# /kaggle/input/test/face05672.jpg
# /kaggle/input/test/face04591.jpg
# /kaggle/input/test/face04367.jpg
# /kaggle/input/test/face00708.jpg
# /kaggle/input/test/face04024.jpg
# /kaggle/input/test/face04886.jpg
# /kaggle/input/test/face03916.jpg
# /kaggle/input/test/face04453.jpg
# /kaggle/input/test/face01013.jpg
# /kaggle/input/test/face04123.jpg
# /kaggle/input/test/face02663.jpg
# /kaggle/input/test/face00160.jpg
# /kaggle/input/test/face04348.jpg
# /kaggle/input/test/face02778.jpg
# /kaggle/input/test/face05879.jpg
# /kaggle/input/test/face05556.jpg
# /kaggle/input/test/face03571.jpg
# /kaggle/input/test/face00411.jpg
# /kaggle/input/test/face05380.jpg
# /kaggle/input/test/face03670.jpg
# /kaggle/input/test/face04034.jpg
# /kaggle/input/test/face00425.jpg
# /kaggle/input/test/face03632.jpg
# /kaggle/input/test/face03316.jpg
# /kaggle/input/test/face02912.jpg
# /kaggle/input/test/face04186.jpg
# /kaggle/input/test/face05161.jpg
# /kaggle/input/test/face00298.jpg
# /kaggle/input/test/face04958.jpg
# /kaggle/input/test/face01795.jpg
# /kaggle/input/test/face01389.jpg
# /kaggle/input/test/face01071.jpg
# /kaggle/input/test/face01381.jpg
# /kaggle/input/test/face01347.jpg
# /kaggle/input/test/face02596.jpg
# /kaggle/input/test/face01345.jpg
# /kaggle/input/test/face06055.jpg
# /kaggle/input/test/face05632.jpg
# /kaggle/input/test/face04835.jpg
# /kaggle/input/test/face00858.jpg
# /kaggle/input/test/face03130.jpg
# /kaggle/input/test/face04181.jpg
# /kaggle/input/test/face02042.jpg
# /kaggle/input/test/face01481.jpg
# /kaggle/input/test/face04536.jpg
# /kaggle/input/test/face02238.jpg
# /kaggle/input/test/face05944.jpg
# /kaggle/input/test/face05837.jpg
# /kaggle/input/test/face00733.jpg
# /kaggle/input/test/face00880.jpg
# /kaggle/input/test/face04730.jpg
# /kaggle/input/test/face03037.jpg
# /kaggle/input/test/face01427.jpg
# /kaggle/input/test/face00863.jpg
# /kaggle/input/test/face03121.jpg
# /kaggle/input/test/face02479.jpg
# /kaggle/input/test/face04412.jpg
# /kaggle/input/test/face06020.jpg
# /kaggle/input/test/face00127.jpg
# /kaggle/input/test/face03335.jpg
# /kaggle/input/test/face00302.jpg
# /kaggle/input/test/face02510.jpg
# /kaggle/input/test/face04502.jpg
# /kaggle/input/test/face02789.jpg
# /kaggle/input/test/face06017.jpg
# /kaggle/input/test/face02530.jpg
# /kaggle/input/test/face01600.jpg
# /kaggle/input/test/face02372.jpg
# /kaggle/input/test/face03066.jpg
# /kaggle/input/test/face00955.jpg
# /kaggle/input/test/face03847.jpg
# /kaggle/input/test/face04374.jpg
# /kaggle/input/test/face03484.jpg
# /kaggle/input/test/face01921.jpg
# /kaggle/input/test/face03188.jpg
# /kaggle/input/test/face05697.jpg
# /kaggle/input/test/face05727.jpg
# /kaggle/input/test/face01667.jpg
# /kaggle/input/test/face03272.jpg
# /kaggle/input/test/face06116.jpg
# /kaggle/input/test/face05573.jpg
# /kaggle/input/test/face01940.jpg
# /kaggle/input/test/face04716.jpg
# /kaggle/input/test/face03202.jpg
# /kaggle/input/test/face03105.jpg
# /kaggle/input/test/face05744.jpg
# /kaggle/input/test/face02334.jpg
# /kaggle/input/test/face04600.jpg
# /kaggle/input/test/face05584.jpg
# /kaggle/input/test/face01429.jpg
# /kaggle/input/test/face04898.jpg
# /kaggle/input/test/face01522.jpg
# /kaggle/input/test/face06177.jpg
# /kaggle/input/test/face02120.jpg
# /kaggle/input/test/face02218.jpg
# /kaggle/input/test/face05471.jpg
# /kaggle/input/test/face03114.jpg
# /kaggle/input/test/face02329.jpg
# /kaggle/input/test/face05269.jpg
# /kaggle/input/test/face04827.jpg
# /kaggle/input/test/face00703.jpg
# /kaggle/input/test/face05587.jpg
# /kaggle/input/test/face00408.jpg
# /kaggle/input/test/face04717.jpg
# /kaggle/input/test/face03578.jpg
# /kaggle/input/test/face00728.jpg
# /kaggle/input/test/face05189.jpg
# /kaggle/input/test/face01916.jpg
# /kaggle/input/test/face02904.jpg
# /kaggle/input/test/face01686.jpg
# /kaggle/input/test/face06050.jpg
# /kaggle/input/test/face01831.jpg
# /kaggle/input/test/face05293.jpg
# /kaggle/input/test/face02702.jpg
# /kaggle/input/test/face01683.jpg
# /kaggle/input/test/face05044.jpg
# /kaggle/input/test/face03696.jpg
# /kaggle/input/test/face00623.jpg
# /kaggle/input/test/face01787.jpg
# /kaggle/input/test/face00506.jpg
# /kaggle/input/test/face02988.jpg
# /kaggle/input/test/face01046.jpg
# /kaggle/input/test/face02143.jpg
# /kaggle/input/test/face02369.jpg
# /kaggle/input/test/face04031.jpg
# /kaggle/input/test/face03873.jpg
# /kaggle/input/test/face03603.jpg
# /kaggle/input/test/face02690.jpg
# /kaggle/input/test/face02260.jpg
# /kaggle/input/test/face01677.jpg
# /kaggle/input/test/face00808.jpg
# /kaggle/input/test/face00959.jpg
# /kaggle/input/test/face04973.jpg
# /kaggle/input/test/face03466.jpg
# /kaggle/input/test/face01332.jpg
# /kaggle/input/test/face05955.jpg
# /kaggle/input/test/face03572.jpg
# /kaggle/input/test/face01744.jpg
# /kaggle/input/test/face02550.jpg
# /kaggle/input/test/face03385.jpg
# /kaggle/input/test/face02818.jpg
# /kaggle/input/test/face06218.jpg
# /kaggle/input/test/face00061.jpg
# /kaggle/input/test/face05085.jpg
# /kaggle/input/test/face00616.jpg
# /kaggle/input/test/face02099.jpg
# /kaggle/input/test/face04667.jpg
# /kaggle/input/test/face00984.jpg
# /kaggle/input/test/face03142.jpg
# /kaggle/input/test/face02829.jpg
# /kaggle/input/test/face04748.jpg
# /kaggle/input/test/face02359.jpg
# /kaggle/input/test/face02477.jpg
# /kaggle/input/test/face05367.jpg
# /kaggle/input/test/face01134.jpg
# /kaggle/input/test/face04819.jpg
# /kaggle/input/test/face06240.jpg
# /kaggle/input/test/face04757.jpg
# /kaggle/input/test/face04005.jpg
# /kaggle/input/test/face02523.jpg
# /kaggle/input/test/face00684.jpg
# /kaggle/input/test/face02373.jpg
# /kaggle/input/test/face05850.jpg
# /kaggle/input/test/face04021.jpg
# /kaggle/input/test/face02705.jpg
# /kaggle/input/test/face02091.jpg
# /kaggle/input/test/face05110.jpg
# /kaggle/input/test/face01129.jpg
# /kaggle/input/test/face05432.jpg
# /kaggle/input/test/face02436.jpg
# /kaggle/input/test/face05606.jpg
# /kaggle/input/test/face01168.jpg
# /kaggle/input/test/face02407.jpg
# /kaggle/input/test/face01675.jpg
# /kaggle/input/test/face04125.jpg
# /kaggle/input/test/face04691.jpg
# /kaggle/input/test/face02852.jpg
# /kaggle/input/test/face01932.jpg
# /kaggle/input/test/face02747.jpg
# /kaggle/input/test/face01680.jpg
# /kaggle/input/test/face05358.jpg
# /kaggle/input/test/face04642.jpg
# /kaggle/input/test/face04534.jpg
# /kaggle/input/test/face02216.jpg
# /kaggle/input/test/face05729.jpg
# /kaggle/input/test/face04006.jpg
# /kaggle/input/test/face04549.jpg
# /kaggle/input/test/face04327.jpg
# /kaggle/input/test/face04517.jpg
# /kaggle/input/test/face03044.jpg
# /kaggle/input/test/face01221.jpg
# /kaggle/input/test/face05772.jpg
# /kaggle/input/test/face00244.jpg
# /kaggle/input/test/face02394.jpg
# /kaggle/input/test/face04485.jpg
# /kaggle/input/test/face05912.jpg
# /kaggle/input/test/face04823.jpg
# /kaggle/input/test/face05745.jpg
# /kaggle/input/test/face03339.jpg
# /kaggle/input/test/face01327.jpg
# /kaggle/input/test/face05301.jpg
# /kaggle/input/test/face01957.jpg
# /kaggle/input/test/face04420.jpg
# /kaggle/input/test/face01649.jpg
# /kaggle/input/test/face03824.jpg
# /kaggle/input/test/face04814.jpg
# /kaggle/input/test/face00501.jpg
# /kaggle/input/test/face01251.jpg
# /kaggle/input/test/face04163.jpg
# /kaggle/input/test/face03772.jpg
# /kaggle/input/test/face04915.jpg
# /kaggle/input/test/face02745.jpg
# /kaggle/input/test/face03443.jpg
# /kaggle/input/test/face06046.jpg
# /kaggle/input/test/face03425.jpg
# /kaggle/input/test/face02657.jpg
# /kaggle/input/test/face00518.jpg
# /kaggle/input/test/face04638.jpg
# /kaggle/input/test/face01985.jpg
# /kaggle/input/test/face04063.jpg
# /kaggle/input/test/face05342.jpg
# /kaggle/input/test/face00402.jpg
# /kaggle/input/test/face00308.jpg
# /kaggle/input/test/face05277.jpg
# /kaggle/input/test/face02604.jpg
# /kaggle/input/test/face00812.jpg
# /kaggle/input/test/face02452.jpg
# /kaggle/input/test/face01434.jpg
# /kaggle/input/test/face04097.jpg
# /kaggle/input/test/face01146.jpg
# /kaggle/input/test/face04047.jpg
# /kaggle/input/test/face04147.jpg
# /kaggle/input/test/face03201.jpg
# /kaggle/input/test/face02655.jpg
# /kaggle/input/test/face02787.jpg
# /kaggle/input/test/face04382.jpg
# /kaggle/input/test/face01329.jpg
# /kaggle/input/test/face05722.jpg
# /kaggle/input/test/face01460.jpg
# /kaggle/input/test/face05522.jpg
# /kaggle/input/test/face01905.jpg
# /kaggle/input/test/face06062.jpg
# /kaggle/input/test/face01711.jpg
# /kaggle/input/test/face04038.jpg
# /kaggle/input/test/face01321.jpg
# /kaggle/input/test/face04550.jpg
# /kaggle/input/test/face05026.jpg
# /kaggle/input/test/face00652.jpg
# /kaggle/input/test/face05241.jpg
# /kaggle/input/test/face05862.jpg
# /kaggle/input/test/face04969.jpg
# /kaggle/input/test/face03103.jpg
# /kaggle/input/test/face04136.jpg
# /kaggle/input/test/face00461.jpg
# /kaggle/input/test/face00569.jpg
# /kaggle/input/test/face03020.jpg
# /kaggle/input/test/face04170.jpg
# /kaggle/input/test/face05064.jpg
# /kaggle/input/test/face02557.jpg
# /kaggle/input/test/face03913.jpg
# /kaggle/input/test/face04934.jpg
# /kaggle/input/test/face00205.jpg
# /kaggle/input/test/face02521.jpg
# /kaggle/input/test/face04071.jpg
# /kaggle/input/test/face04254.jpg
# /kaggle/input/test/face01596.jpg
# /kaggle/input/test/face04402.jpg
# /kaggle/input/test/face02244.jpg
# /kaggle/input/test/face02072.jpg
# /kaggle/input/test/face01036.jpg
# /kaggle/input/test/face03626.jpg
# /kaggle/input/test/face06201.jpg
# /kaggle/input/test/face04848.jpg
# /kaggle/input/test/face05295.jpg
# /kaggle/input/test/face02981.jpg
# /kaggle/input/test/face03440.jpg
# /kaggle/input/test/face03752.jpg
# /kaggle/input/test/face03899.jpg
# /kaggle/input/test/face04489.jpg
# /kaggle/input/test/face03340.jpg
# /kaggle/input/test/face02031.jpg
# /kaggle/input/test/face04212.jpg
# /kaggle/input/test/face04830.jpg
# /kaggle/input/test/face04521.jpg
# /kaggle/input/test/face01138.jpg
# /kaggle/input/test/face05036.jpg
# /kaggle/input/test/face02793.jpg
# /kaggle/input/test/face00691.jpg
# /kaggle/input/test/face00962.jpg
# /kaggle/input/test/face04594.jpg
# /kaggle/input/test/face03633.jpg
# /kaggle/input/test/face02175.jpg
# /kaggle/input/test/face03776.jpg
# /kaggle/input/test/face01826.jpg
# /kaggle/input/test/face05638.jpg
# /kaggle/input/test/face01973.jpg
# /kaggle/input/test/face03043.jpg
# /kaggle/input/test/face04272.jpg
# /kaggle/input/test/face01245.jpg
# /kaggle/input/test/face04220.jpg
# /kaggle/input/test/face01314.jpg
# /kaggle/input/test/face02370.jpg
# /kaggle/input/test/face05551.jpg
# /kaggle/input/test/face02186.jpg
# /kaggle/input/test/face04870.jpg
# /kaggle/input/test/face06120.jpg
# /kaggle/input/test/face04511.jpg
# /kaggle/input/test/face04036.jpg
# /kaggle/input/test/face04397.jpg
# /kaggle/input/test/face02013.jpg
# /kaggle/input/test/face01349.jpg
# /kaggle/input/test/face04205.jpg
# /kaggle/input/test/face01030.jpg
# /kaggle/input/test/face04281.jpg
# /kaggle/input/test/face04544.jpg
# /kaggle/input/test/face04901.jpg
# /kaggle/input/test/face01967.jpg
# /kaggle/input/test/face06003.jpg
# /kaggle/input/test/face02212.jpg
# /kaggle/input/test/face00629.jpg
# /kaggle/input/test/face03018.jpg
# /kaggle/input/test/face03462.jpg
# /kaggle/input/test/face02620.jpg
# /kaggle/input/test/face05028.jpg
# /kaggle/input/test/face02358.jpg
# /kaggle/input/test/face00913.jpg
# /kaggle/input/test/face06188.jpg
# /kaggle/input/test/face03918.jpg
# /kaggle/input/test/face06039.jpg
# /kaggle/input/test/face02942.jpg
# /kaggle/input/test/face03321.jpg
# /kaggle/input/test/face05567.jpg
# /kaggle/input/test/face00743.jpg
# /kaggle/input/test/face05943.jpg
# /kaggle/input/test/face05990.jpg
# /kaggle/input/test/face05789.jpg
# /kaggle/input/test/face05874.jpg
# /kaggle/input/test/face02295.jpg
# /kaggle/input/test/face04735.jpg
# /kaggle/input/test/face00114.jpg
# /kaggle/input/test/face00426.jpg
# /kaggle/input/test/face03158.jpg
# /kaggle/input/test/face00638.jpg
# /kaggle/input/test/face04185.jpg
# /kaggle/input/test/face03704.jpg
# /kaggle/input/test/face04368.jpg
# /kaggle/input/test/face04398.jpg
# /kaggle/input/test/face01281.jpg
# /kaggle/input/test/face02991.jpg
# /kaggle/input/test/face03754.jpg
# /kaggle/input/test/face03330.jpg
# /kaggle/input/test/face03437.jpg
# /kaggle/input/test/face02555.jpg
# /kaggle/input/test/face06053.jpg
# /kaggle/input/test/face06144.jpg
# /kaggle/input/test/face03693.jpg
# /kaggle/input/test/face01915.jpg
# /kaggle/input/test/face01693.jpg
# /kaggle/input/test/face02467.jpg
# /kaggle/input/test/face01499.jpg
# /kaggle/input/test/face03514.jpg
# /kaggle/input/test/face00031.jpg
# /kaggle/input/test/face05007.jpg
# /kaggle/input/test/face00140.jpg
# /kaggle/input/test/face02910.jpg
# /kaggle/input/test/face06204.jpg
# /kaggle/input/test/face03498.jpg
# /kaggle/input/test/face03660.jpg
# /kaggle/input/test/face04979.jpg
# /kaggle/input/test/face00615.jpg
# /kaggle/input/test/face05320.jpg
# /kaggle/input/test/face05418.jpg
# /kaggle/input/test/face00219.jpg
# /kaggle/input/test/face02784.jpg
# /kaggle/input/test/face04554.jpg
# /kaggle/input/test/face03145.jpg
# /kaggle/input/test/face02975.jpg
# /kaggle/input/test/face03581.jpg
# /kaggle/input/test/face03905.jpg
# /kaggle/input/test/face01372.jpg
# /kaggle/input/test/face02835.jpg
# /kaggle/input/test/face01903.jpg
# /kaggle/input/test/face05703.jpg
# /kaggle/input/test/face01111.jpg
# /kaggle/input/test/face00945.jpg
# /kaggle/input/test/face06152.jpg
# /kaggle/input/test/face03394.jpg
# /kaggle/input/test/face00941.jpg
# /kaggle/input/test/face05542.jpg
# /kaggle/input/test/face00311.jpg
# /kaggle/input/test/face03371.jpg
# /kaggle/input/test/face05387.jpg
# /kaggle/input/test/face05308.jpg
# /kaggle/input/test/face01722.jpg
# /kaggle/input/test/face01837.jpg
# /kaggle/input/test/face01609.jpg
# /kaggle/input/test/face05646.jpg
# /kaggle/input/test/face06013.jpg
# /kaggle/input/test/face02432.jpg
# /kaggle/input/test/face02415.jpg
# /kaggle/input/test/face03932.jpg
# /kaggle/input/test/face01414.jpg
# /kaggle/input/test/face02349.jpg
# /kaggle/input/test/face01080.jpg
# /kaggle/input/test/face00610.jpg
# /kaggle/input/test/face00107.jpg
# /kaggle/input/test/face05686.jpg
# /kaggle/input/test/face05411.jpg
# /kaggle/input/test/face06105.jpg
# /kaggle/input/test/face03141.jpg
# /kaggle/input/test/face00884.jpg
# /kaggle/input/test/face01773.jpg
# /kaggle/input/test/face04984.jpg
# /kaggle/input/test/face05335.jpg
# /kaggle/input/test/face05705.jpg
# /kaggle/input/test/face03480.jpg
# /kaggle/input/test/face02893.jpg
# /kaggle/input/test/face00136.jpg
# /kaggle/input/test/face03229.jpg
# /kaggle/input/test/face03980.jpg
# /kaggle/input/test/face06052.jpg
# /kaggle/input/test/face03164.jpg
# /kaggle/input/test/face01822.jpg
# /kaggle/input/test/face01401.jpg
# /kaggle/input/test/face00346.jpg
# /kaggle/input/test/face04908.jpg
# /kaggle/input/test/face04683.jpg
# /kaggle/input/test/face01566.jpg
# /kaggle/input/test/face01579.jpg
# /kaggle/input/test/face01318.jpg
# /kaggle/input/test/face03967.jpg
# /kaggle/input/test/face03162.jpg
# /kaggle/input/test/face02423.jpg
# /kaggle/input/test/face05338.jpg
# /kaggle/input/test/face05670.jpg
# /kaggle/input/test/face02589.jpg
# /kaggle/input/test/face04253.jpg
# /kaggle/input/test/face05793.jpg
# /kaggle/input/test/face01754.jpg
# /kaggle/input/test/face05797.jpg
# /kaggle/input/test/face03656.jpg
# /kaggle/input/test/face01304.jpg
# /kaggle/input/test/face00470.jpg
# /kaggle/input/test/face01721.jpg
# /kaggle/input/test/face03222.jpg
# /kaggle/input/test/face01399.jpg
# /kaggle/input/test/face02678.jpg
# /kaggle/input/test/face02884.jpg
# /kaggle/input/test/face06219.jpg
# /kaggle/input/test/face03517.jpg
# /kaggle/input/test/face03708.jpg
# /kaggle/input/test/face05735.jpg
# /kaggle/input/test/face03214.jpg
# /kaggle/input/test/face05569.jpg
# /kaggle/input/test/face03493.jpg
# /kaggle/input/test/face01106.jpg
# /kaggle/input/test/face06022.jpg
# /kaggle/input/test/face02363.jpg
# /kaggle/input/test/face00529.jpg
# /kaggle/input/test/face01166.jpg
# /kaggle/input/test/face04751.jpg
# /kaggle/input/test/face04520.jpg
# /kaggle/input/test/face03040.jpg
# /kaggle/input/test/face05770.jpg
# /kaggle/input/test/face00796.jpg
# /kaggle/input/test/face00813.jpg
# /kaggle/input/test/face04560.jpg
# /kaggle/input/test/face05278.jpg
# /kaggle/input/test/face02328.jpg
# /kaggle/input/test/face05199.jpg
# /kaggle/input/test/face03675.jpg
# /kaggle/input/test/face02233.jpg
# /kaggle/input/test/face02728.jpg
# /kaggle/input/test/face04573.jpg
# /kaggle/input/test/face03282.jpg
# /kaggle/input/test/face04786.jpg
# /kaggle/input/test/face02300.jpg
# /kaggle/input/test/face02651.jpg
# /kaggle/input/test/face00318.jpg
# /kaggle/input/test/face01886.jpg
# /kaggle/input/test/face02083.jpg
# /kaggle/input/test/face05215.jpg
# /kaggle/input/test/face02121.jpg
# /kaggle/input/test/face02315.jpg
# /kaggle/input/test/face00643.jpg
# /kaggle/input/test/face03963.jpg
# /kaggle/input/test/face00366.jpg
# /kaggle/input/test/face03285.jpg
# /kaggle/input/test/face01231.jpg
# /kaggle/input/test/face02937.jpg
# /kaggle/input/test/face01695.jpg
# /kaggle/input/test/face01444.jpg
# /kaggle/input/test/face03195.jpg
# /kaggle/input/test/face02798.jpg
# /kaggle/input/test/face02102.jpg
# /kaggle/input/test/face02919.jpg
# /kaggle/input/test/face05611.jpg
# /kaggle/input/test/face05118.jpg
# /kaggle/input/test/face03344.jpg
# /kaggle/input/test/face00009.jpg
# /kaggle/input/test/face05361.jpg
# /kaggle/input/test/face05859.jpg
# /kaggle/input/test/face02067.jpg
# /kaggle/input/test/face04470.jpg
# /kaggle/input/test/face04756.jpg
# /kaggle/input/test/face00474.jpg
# /kaggle/input/test/face03357.jpg
# /kaggle/input/test/face05490.jpg
# /kaggle/input/test/face01682.jpg
# /kaggle/input/test/face03280.jpg
# /kaggle/input/test/face01875.jpg
# /kaggle/input/test/face00595.jpg
# /kaggle/input/test/face06176.jpg
# /kaggle/input/test/face00906.jpg
# /kaggle/input/test/face00069.jpg
# /kaggle/input/test/face01014.jpg
# /kaggle/input/test/face04369.jpg
# /kaggle/input/test/face05394.jpg
# /kaggle/input/test/face02525.jpg
# /kaggle/input/test/face01857.jpg
# /kaggle/input/test/face02581.jpg
# /kaggle/input/test/face00343.jpg
# /kaggle/input/test/face01004.jpg
# /kaggle/input/test/face02085.jpg
# /kaggle/input/test/face02559.jpg
# /kaggle/input/test/face03024.jpg
# /kaggle/input/test/face04861.jpg
# /kaggle/input/test/face06014.jpg
# /kaggle/input/test/face05254.jpg
# /kaggle/input/test/face05102.jpg
# /kaggle/input/test/face05706.jpg
# /kaggle/input/test/face02631.jpg
# /kaggle/input/test/face01397.jpg
# /kaggle/input/test/face00049.jpg
# /kaggle/input/test/face03927.jpg
# /kaggle/input/test/face00668.jpg
# /kaggle/input/test/face01842.jpg
# /kaggle/input/test/face02697.jpg
# /kaggle/input/test/face01997.jpg
# /kaggle/input/test/face04899.jpg
# /kaggle/input/test/face01400.jpg
# /kaggle/input/test/face00830.jpg
# /kaggle/input/test/face03116.jpg
# /kaggle/input/test/face05700.jpg
# /kaggle/input/test/face02693.jpg
# /kaggle/input/test/face04143.jpg
# /kaggle/input/test/face00355.jpg
# /kaggle/input/test/face04229.jpg
# /kaggle/input/test/face04692.jpg
# /kaggle/input/test/face03428.jpg
# /kaggle/input/test/face01215.jpg
# /kaggle/input/test/face03534.jpg
# /kaggle/input/test/face03908.jpg
# /kaggle/input/test/face05428.jpg
# /kaggle/input/test/face01800.jpg
# /kaggle/input/test/face03862.jpg
# /kaggle/input/test/face03252.jpg
# /kaggle/input/test/face06167.jpg
# /kaggle/input/test/face05539.jpg
# /kaggle/input/test/face05711.jpg
# /kaggle/input/test/face01658.jpg
# /kaggle/input/test/face00536.jpg
# /kaggle/input/test/face04086.jpg
# /kaggle/input/test/face06260.jpg
# /kaggle/input/test/face05359.jpg
# /kaggle/input/test/face03250.jpg
# /kaggle/input/test/face06019.jpg
# /kaggle/input/test/face03758.jpg
# /kaggle/input/test/face04798.jpg
# /kaggle/input/test/face00176.jpg
# /kaggle/input/test/face03854.jpg
# /kaggle/input/test/face01107.jpg
# /kaggle/input/test/face00256.jpg
# /kaggle/input/test/face03101.jpg
# /kaggle/input/test/face02860.jpg
# /kaggle/input/test/face00964.jpg
# /kaggle/input/test/face03769.jpg
# /kaggle/input/test/face05467.jpg
# /kaggle/input/test/face04850.jpg
# /kaggle/input/test/face00940.jpg
# /kaggle/input/test/face04705.jpg
# /kaggle/input/test/face01560.jpg
# /kaggle/input/test/face01098.jpg
# /kaggle/input/test/face04015.jpg
# /kaggle/input/test/face00794.jpg
# /kaggle/input/test/face03770.jpg
# /kaggle/input/test/face02736.jpg
# /kaggle/input/test/face04602.jpg
# /kaggle/input/test/face02383.jpg
# /kaggle/input/test/face00493.jpg
# /kaggle/input/test/face03883.jpg
# /kaggle/input/test/face00139.jpg
# /kaggle/input/test/face00163.jpg
# /kaggle/input/test/face02481.jpg
# /kaggle/input/test/face01895.jpg
# /kaggle/input/test/face05629.jpg
# /kaggle/input/test/face00499.jpg
# /kaggle/input/test/face05845.jpg
# /kaggle/input/test/face04089.jpg
# /kaggle/input/test/face04400.jpg
# /kaggle/input/test/face05043.jpg
# /kaggle/input/test/face05091.jpg
# /kaggle/input/test/face01062.jpg
# /kaggle/input/test/face00840.jpg
# /kaggle/input/test/face03613.jpg
# /kaggle/input/test/face02990.jpg
# /kaggle/input/test/face00352.jpg
# /kaggle/input/test/face03866.jpg
# /kaggle/input/test/face05014.jpg
# /kaggle/input/test/face04701.jpg
# /kaggle/input/test/face05166.jpg
# /kaggle/input/test/face04811.jpg
# /kaggle/input/test/face01794.jpg
# /kaggle/input/test/face01544.jpg
# /kaggle/input/test/face03411.jpg
# /kaggle/input/test/face03457.jpg
# /kaggle/input/test/face05218.jpg
# /kaggle/input/test/face01110.jpg
# /kaggle/input/test/face01087.jpg
# /kaggle/input/test/face01611.jpg
# /kaggle/input/test/face04108.jpg
# /kaggle/input/test/face04460.jpg
# /kaggle/input/test/face01083.jpg
# /kaggle/input/test/face05315.jpg
# /kaggle/input/test/face01130.jpg
# /kaggle/input/test/face03765.jpg
# /kaggle/input/test/face06200.jpg
# /kaggle/input/test/face01217.jpg
# /kaggle/input/test/face01371.jpg
# /kaggle/input/test/face00348.jpg
# /kaggle/input/test/face01385.jpg
# /kaggle/input/test/face05628.jpg
# /kaggle/input/test/face05913.jpg
# /kaggle/input/test/face05132.jpg
# /kaggle/input/test/face05193.jpg
# /kaggle/input/test/face02699.jpg
# /kaggle/input/test/face00861.jpg
# /kaggle/input/test/face05033.jpg
# /kaggle/input/test/face00719.jpg
# /kaggle/input/test/face03659.jpg
# /kaggle/input/test/face03454.jpg
# /kaggle/input/test/face04476.jpg
# /kaggle/input/test/face05866.jpg
# /kaggle/input/test/face00338.jpg
# /kaggle/input/test/face01781.jpg
# /kaggle/input/test/face03755.jpg
# /kaggle/input/test/face06211.jpg
# /kaggle/input/test/face00958.jpg
# /kaggle/input/test/face06085.jpg
# /kaggle/input/test/face01383.jpg
# /kaggle/input/test/face01012.jpg
# /kaggle/input/test/face01867.jpg
# /kaggle/input/test/face03853.jpg
# /kaggle/input/test/face01959.jpg
# /kaggle/input/test/face01845.jpg
# /kaggle/input/test/face03645.jpg
# /kaggle/input/test/face06063.jpg
# /kaggle/input/test/face01628.jpg
# /kaggle/input/test/face05154.jpg
# /kaggle/input/test/face05954.jpg
# /kaggle/input/test/face04357.jpg
# /kaggle/input/test/face05869.jpg
# /kaggle/input/test/face05691.jpg
# /kaggle/input/test/face04479.jpg
# /kaggle/input/test/face00803.jpg
# /kaggle/input/test/face04249.jpg
# /kaggle/input/test/face05415.jpg
# /kaggle/input/test/face00667.jpg
# /kaggle/input/test/face02646.jpg
# /kaggle/input/test/face03061.jpg
# /kaggle/input/test/face03741.jpg
# /kaggle/input/test/face03491.jpg
# /kaggle/input/test/face03729.jpg
# /kaggle/input/test/face02135.jpg
# /kaggle/input/test/face04001.jpg
# /kaggle/input/test/face05961.jpg
# /kaggle/input/test/face02906.jpg
# /kaggle/input/test/face05540.jpg
# /kaggle/input/test/face03592.jpg
# /kaggle/input/test/face04192.jpg
# /kaggle/input/test/face02263.jpg
# /kaggle/input/test/face06114.jpg
# /kaggle/input/test/face00677.jpg
# /kaggle/input/test/face00006.jpg
# /kaggle/input/test/face05734.jpg
# /kaggle/input/test/face02064.jpg
# /kaggle/input/test/face02455.jpg
# /kaggle/input/test/face00846.jpg
# /kaggle/input/test/face04243.jpg
# /kaggle/input/test/face06256.jpg
# /kaggle/input/test/face05740.jpg
# /kaggle/input/test/face04193.jpg
# /kaggle/input/test/face05175.jpg
# /kaggle/input/test/face02055.jpg
# /kaggle/input/test/face00896.jpg
# /kaggle/input/test/face05448.jpg
# /kaggle/input/test/face00663.jpg
# /kaggle/input/test/face04597.jpg
# /kaggle/input/test/face01179.jpg
# /kaggle/input/test/face06184.jpg
# /kaggle/input/test/face04883.jpg
# /kaggle/input/test/face03973.jpg
# /kaggle/input/test/face03961.jpg
# /kaggle/input/test/face01310.jpg
# /kaggle/input/test/face05631.jpg
# /kaggle/input/test/face04266.jpg
# /kaggle/input/test/face02181.jpg
# /kaggle/input/test/face03060.jpg
# /kaggle/input/test/face00033.jpg
# /kaggle/input/test/face04217.jpg
# /kaggle/input/test/face01523.jpg
# /kaggle/input/test/face00797.jpg
# /kaggle/input/test/face00645.jpg
# /kaggle/input/test/face01911.jpg
# /kaggle/input/test/face02972.jpg
# /kaggle/input/test/face02130.jpg
# /kaggle/input/test/face02839.jpg
# /kaggle/input/test/face04459.jpg
# /kaggle/input/test/face03064.jpg
# /kaggle/input/test/face00712.jpg
# /kaggle/input/test/face05560.jpg
# /kaggle/input/test/face01052.jpg
# /kaggle/input/test/face01719.jpg
# /kaggle/input/test/face01830.jpg
# /kaggle/input/test/face01766.jpg
# /kaggle/input/test/face04154.jpg
# /kaggle/input/test/face03178.jpg
# /kaggle/input/test/face06090.jpg
# /kaggle/input/test/face00188.jpg
# /kaggle/input/test/face00358.jpg
# /kaggle/input/test/face00579.jpg
# /kaggle/input/test/face03108.jpg
# /kaggle/input/test/face01356.jpg
# /kaggle/input/test/face00018.jpg
# /kaggle/input/test/face05124.jpg
# /kaggle/input/test/face04992.jpg
# /kaggle/input/test/face05723.jpg
# /kaggle/input/test/face02236.jpg
# /kaggle/input/test/face01574.jpg
# /kaggle/input/test/face00449.jpg
# /kaggle/input/test/face05755.jpg
# /kaggle/input/test/face02938.jpg
# /kaggle/input/test/face04851.jpg
# /kaggle/input/test/face05605.jpg
# /kaggle/input/test/face01891.jpg
# /kaggle/input/test/face05957.jpg
# /kaggle/input/test/face02776.jpg
# /kaggle/input/test/face02183.jpg
# /kaggle/input/test/face01510.jpg
# /kaggle/input/test/face01015.jpg
# /kaggle/input/test/face00968.jpg
# /kaggle/input/test/face05084.jpg
# /kaggle/input/test/face01090.jpg
# /kaggle/input/test/face02451.jpg
# /kaggle/input/test/face01198.jpg
# /kaggle/input/test/face06187.jpg
# /kaggle/input/test/face06133.jpg
# /kaggle/input/test/face04986.jpg
# /kaggle/input/test/face02973.jpg
# /kaggle/input/test/face00321.jpg
# /kaggle/input/test/face02435.jpg
# /kaggle/input/test/face05581.jpg
# /kaggle/input/test/face01945.jpg
# /kaggle/input/test/face04314.jpg
# /kaggle/input/test/face04809.jpg
# /kaggle/input/test/face04366.jpg
# /kaggle/input/test/face03889.jpg
# /kaggle/input/test/face00253.jpg
# /kaggle/input/test/face05975.jpg
# /kaggle/input/test/face00389.jpg
# /kaggle/input/test/face01122.jpg
# /kaggle/input/test/face00307.jpg
# /kaggle/input/test/face05382.jpg
# /kaggle/input/test/face02336.jpg
# /kaggle/input/test/face03941.jpg
# /kaggle/input/test/face02269.jpg
# /kaggle/input/test/face01343.jpg
# /kaggle/input/test/face05190.jpg
# /kaggle/input/test/face01328.jpg
# /kaggle/input/test/face02684.jpg
# /kaggle/input/test/face02737.jpg
# /kaggle/input/test/face05331.jpg
# /kaggle/input/test/face05319.jpg
# /kaggle/input/test/face00864.jpg
# /kaggle/input/test/face05318.jpg
# /kaggle/input/test/face01786.jpg
# /kaggle/input/test/face05938.jpg
# /kaggle/input/test/face03355.jpg
# /kaggle/input/test/face05510.jpg
# /kaggle/input/test/face04251.jpg
# /kaggle/input/test/face01454.jpg
# /kaggle/input/test/face00759.jpg
# /kaggle/input/test/face03679.jpg
# /kaggle/input/test/face06164.jpg
# /kaggle/input/test/face04076.jpg
# /kaggle/input/test/face02485.jpg
# /kaggle/input/test/face00594.jpg
# /kaggle/input/test/face04094.jpg
# /kaggle/input/test/face05299.jpg
# /kaggle/input/test/face03071.jpg
# /kaggle/input/test/face00335.jpg
# /kaggle/input/test/face05403.jpg
# /kaggle/input/test/face01812.jpg
# /kaggle/input/test/face02908.jpg
# /kaggle/input/test/face02348.jpg
# /kaggle/input/test/face03818.jpg
# /kaggle/input/test/face04741.jpg
# /kaggle/input/test/face04331.jpg
# /kaggle/input/test/face02462.jpg
# /kaggle/input/test/face03180.jpg
# /kaggle/input/test/face00288.jpg
# /kaggle/input/test/face01902.jpg
# /kaggle/input/test/face01363.jpg
# /kaggle/input/test/face01189.jpg
# /kaggle/input/test/face01896.jpg
# /kaggle/input/test/face04733.jpg
# /kaggle/input/test/face00371.jpg
# /kaggle/input/test/face01862.jpg
# /kaggle/input/test/face01558.jpg
# /kaggle/input/test/face01716.jpg
# /kaggle/input/test/face01374.jpg
# /kaggle/input/test/face01017.jpg
# /kaggle/input/test/face03403.jpg
# /kaggle/input/test/face02282.jpg
# /kaggle/input/test/face02221.jpg
# /kaggle/input/test/face01882.jpg
# /kaggle/input/test/face05139.jpg
# /kaggle/input/test/face05261.jpg
# /kaggle/input/test/face03822.jpg
# /kaggle/input/test/face02597.jpg
# /kaggle/input/test/face02184.jpg
# /kaggle/input/test/face01718.jpg
# /kaggle/input/test/face02688.jpg
# /kaggle/input/test/face04318.jpg
# /kaggle/input/test/face02846.jpg
# /kaggle/input/test/face03863.jpg
# /kaggle/input/test/face04223.jpg
# /kaggle/input/test/face04845.jpg
# /kaggle/input/test/face00975.jpg
# /kaggle/input/test/face01998.jpg
# /kaggle/input/test/face01282.jpg
# /kaggle/input/test/face05140.jpg
# /kaggle/input/test/face05687.jpg
# /kaggle/input/test/face04481.jpg
# /kaggle/input/test/face03395.jpg
# /kaggle/input/test/face00554.jpg
# /kaggle/input/test/face04962.jpg
# /kaggle/input/test/face02390.jpg
# /kaggle/input/test/face03768.jpg
# /kaggle/input/test/face00535.jpg
# /kaggle/input/test/face06205.jpg
# /kaggle/input/test/face01612.jpg
# /kaggle/input/test/face03301.jpg
# /kaggle/input/test/face06064.jpg
# /kaggle/input/test/face03150.jpg
# /kaggle/input/test/face01691.jpg
# /kaggle/input/test/face04639.jpg
# /kaggle/input/test/face01996.jpg
# /kaggle/input/test/face03688.jpg
# /kaggle/input/test/face02955.jpg
# /kaggle/input/test/face00609.jpg
# /kaggle/input/test/face01739.jpg
# /kaggle/input/test/face01980.jpg
# /kaggle/input/test/face00608.jpg
# /kaggle/input/test/face03643.jpg
# /kaggle/input/test/face03753.jpg
# /kaggle/input/test/face01776.jpg
# /kaggle/input/test/face00561.jpg
# /kaggle/input/test/face00060.jpg
# /kaggle/input/test/face04512.jpg
# /kaggle/input/test/face01944.jpg
# /kaggle/input/test/face02078.jpg
# /kaggle/input/test/face02119.jpg
# /kaggle/input/test/face04601.jpg
# /kaggle/input/test/face04825.jpg
# /kaggle/input/test/face01209.jpg
# /kaggle/input/test/face01994.jpg
# /kaggle/input/test/face01968.jpg
# /kaggle/input/test/face00982.jpg
# /kaggle/input/test/face04794.jpg
# /kaggle/input/test/face04724.jpg
# /kaggle/input/test/face05962.jpg
# /kaggle/input/test/face00953.jpg
# /kaggle/input/test/face02048.jpg
# /kaggle/input/test/face00227.jpg
# /kaggle/input/test/face05104.jpg
# /kaggle/input/test/face03479.jpg
# /kaggle/input/test/face02109.jpg
# /kaggle/input/test/face02836.jpg
# /kaggle/input/test/face04269.jpg
# /kaggle/input/test/face02144.jpg
# /kaggle/input/test/face01855.jpg
# /kaggle/input/test/face00617.jpg
# /kaggle/input/test/face03412.jpg
# /kaggle/input/test/face01066.jpg
# /kaggle/input/test/face02032.jpg
# /kaggle/input/test/face03226.jpg
# /kaggle/input/test/face01775.jpg
# /kaggle/input/test/face00888.jpg
# /kaggle/input/test/face03318.jpg
# /kaggle/input/test/face02356.jpg
# /kaggle/input/test/face05917.jpg
# /kaggle/input/test/face01513.jpg
# /kaggle/input/test/face02487.jpg
# /kaggle/input/test/face05941.jpg
# /kaggle/input/test/face00873.jpg
# /kaggle/input/test/face03118.jpg
# /kaggle/input/test/face02743.jpg
# /kaggle/input/test/face04100.jpg
# /kaggle/input/test/face02957.jpg
# /kaggle/input/test/face05131.jpg
# /kaggle/input/test/face01435.jpg
# /kaggle/input/test/face02106.jpg
# /kaggle/input/test/face03090.jpg
# /kaggle/input/test/face05248.jpg
# /kaggle/input/test/face03810.jpg
# /kaggle/input/test/face02783.jpg
# /kaggle/input/test/face01379.jpg
# /kaggle/input/test/face03219.jpg
# /kaggle/input/test/face03453.jpg
# /kaggle/input/test/face05847.jpg
# /kaggle/input/test/face01325.jpg
# /kaggle/input/test/face04354.jpg
# /kaggle/input/test/face05390.jpg
# /kaggle/input/test/face02252.jpg
# /kaggle/input/test/face03971.jpg
# /kaggle/input/test/face05350.jpg
# /kaggle/input/test/face01048.jpg
# /kaggle/input/test/face03775.jpg
# /kaggle/input/test/face05842.jpg
# /kaggle/input/test/face01720.jpg
# /kaggle/input/test/face01732.jpg
# /kaggle/input/test/face01258.jpg
# /kaggle/input/test/face01408.jpg
# /kaggle/input/test/face01067.jpg
# /kaggle/input/test/face03738.jpg
# /kaggle/input/test/face01954.jpg
# /kaggle/input/test/face04225.jpg
# /kaggle/input/test/face03342.jpg
# /kaggle/input/test/face00236.jpg
# /kaggle/input/test/face04307.jpg
# /kaggle/input/test/face03837.jpg
# /kaggle/input/test/face04795.jpg
# /kaggle/input/test/face00627.jpg
# /kaggle/input/test/face00096.jpg
# /kaggle/input/test/face00907.jpg
# /kaggle/input/test/face06027.jpg
# /kaggle/input/test/face03667.jpg
# /kaggle/input/test/face02112.jpg
# /kaggle/input/test/face03766.jpg
# /kaggle/input/test/face02211.jpg
# /kaggle/input/test/face03990.jpg
# /kaggle/input/test/face03120.jpg
# /kaggle/input/test/face00120.jpg
# /kaggle/input/test/face04173.jpg
# /kaggle/input/test/face01384.jpg
# /kaggle/input/test/face05465.jpg
# /kaggle/input/test/face05027.jpg
# /kaggle/input/test/face03608.jpg
# /kaggle/input/test/face05001.jpg
# /kaggle/input/test/face02719.jpg
# /kaggle/input/test/face03442.jpg
# /kaggle/input/test/face02772.jpg
# /kaggle/input/test/face05354.jpg
# /kaggle/input/test/face05760.jpg
# /kaggle/input/test/face03058.jpg
# /kaggle/input/test/face03212.jpg
# /kaggle/input/test/face04595.jpg
# /kaggle/input/test/face01536.jpg
# /kaggle/input/test/face03261.jpg
# /kaggle/input/test/face03019.jpg
# /kaggle/input/test/face05991.jpg
# /kaggle/input/test/face00929.jpg
# /kaggle/input/test/face00336.jpg
# /kaggle/input/test/face01679.jpg
# /kaggle/input/test/face04267.jpg
# /kaggle/input/test/face03474.jpg
# /kaggle/input/test/face00475.jpg
# /kaggle/input/test/face04954.jpg
# /kaggle/input/test/face05613.jpg
# /kaggle/input/test/face01308.jpg
# /kaggle/input/test/face02442.jpg
# /kaggle/input/test/face04282.jpg
# /kaggle/input/test/face04026.jpg
# /kaggle/input/test/face00476.jpg
# /kaggle/input/test/face05588.jpg
# /kaggle/input/test/face03423.jpg
# /kaggle/input/test/face05312.jpg
# /kaggle/input/test/face00487.jpg
# /kaggle/input/test/face00349.jpg
# /kaggle/input/test/face03073.jpg
# /kaggle/input/test/face00726.jpg
# /kaggle/input/test/face02608.jpg
# /kaggle/input/test/face00915.jpg
# /kaggle/input/test/face02255.jpg
# /kaggle/input/test/face05038.jpg
# /kaggle/input/test/face04985.jpg
# /kaggle/input/test/face02386.jpg
# /kaggle/input/test/face01458.jpg
# /kaggle/input/test/face05466.jpg
# /kaggle/input/test/face03191.jpg
# /kaggle/input/test/face06151.jpg
# /kaggle/input/test/face03548.jpg
# /kaggle/input/test/face05814.jpg
# /kaggle/input/test/face03502.jpg
# /kaggle/input/test/face04419.jpg
# /kaggle/input/test/face05725.jpg
# /kaggle/input/test/face03184.jpg
# /kaggle/input/test/face00373.jpg
# /kaggle/input/test/face04635.jpg
# /kaggle/input/test/face05776.jpg
# /kaggle/input/test/face05194.jpg
# /kaggle/input/test/face03123.jpg
# /kaggle/input/test/face04451.jpg
# /kaggle/input/test/face01816.jpg
# /kaggle/input/test/face05398.jpg
# /kaggle/input/test/face00838.jpg
# /kaggle/input/test/face00509.jpg
# /kaggle/input/test/face00079.jpg
# /kaggle/input/test/face05904.jpg
# /kaggle/input/test/face06047.jpg
# /kaggle/input/test/face05117.jpg
# /kaggle/input/test/face03596.jpg
# /kaggle/input/test/face00457.jpg
# /kaggle/input/test/face00239.jpg
# /kaggle/input/test/face03631.jpg
# /kaggle/input/test/face02284.jpg
# /kaggle/input/test/face00775.jpg
# /kaggle/input/test/face02292.jpg
# /kaggle/input/test/face00922.jpg
# /kaggle/input/test/face05496.jpg
# /kaggle/input/test/face05728.jpg
# /kaggle/input/test/face00278.jpg
# /kaggle/input/test/face00354.jpg
# /kaggle/input/test/face01024.jpg
# /kaggle/input/test/face04145.jpg
# /kaggle/input/test/face06112.jpg
# /kaggle/input/test/face02832.jpg
# /kaggle/input/test/face05222.jpg
# /kaggle/input/test/face05639.jpg
# /kaggle/input/test/face00965.jpg
# /kaggle/input/test/face03832.jpg
# /kaggle/input/test/face00416.jpg
# /kaggle/input/test/face00765.jpg
# /kaggle/input/test/face02769.jpg
# /kaggle/input/test/face01585.jpg
# /kaggle/input/test/face06141.jpg
# /kaggle/input/test/face01727.jpg
# /kaggle/input/test/face05468.jpg
# /kaggle/input/test/face04865.jpg
# /kaggle/input/test/face03304.jpg
# /kaggle/input/test/face00072.jpg
# /kaggle/input/test/face02956.jpg
# /kaggle/input/test/face00068.jpg
# /kaggle/input/test/face03694.jpg
# /kaggle/input/test/face05786.jpg
# /kaggle/input/test/face03022.jpg
# /kaggle/input/test/face00676.jpg
# /kaggle/input/test/face04077.jpg
# ...
# /kaggle/input/train/F0010/MID3/P00110_face1.jpg
# /kaggle/input/train/F0010/MID3/P00111_face4.jpg
# /kaggle/input/train/F0010/MID3/P00106_face3.jpg
# /kaggle/input/train/F0010/MID4/P00111_face1.jpg
# /kaggle/input/train/F0010/MID4/P00112_face1.jpg
# /kaggle/input/train/F0010/MID4/P00110_face4.jpg
# /kaggle/input/train/F0010/MID4/P00107_face2.jpg
# /kaggle/input/train/F0010/MID4/P00106_face2.jpg
# /kaggle/input/train/F0010/MID2/P00112_face3.jpg
# /kaggle/input/train/F0010/MID2/P00107_face1.jpg
# /kaggle/input/train/F0010/MID2/P00106_face1.jpg
# /kaggle/input/train/F0010/MID2/P00103_face1.jpg
# /kaggle/input/train/F0010/MID2/P00111_face3.jpg
# /kaggle/input/train/F0010/MID2/P00104_face1.jpg
# /kaggle/input/train/F0010/MID2/P00110_face2.jpg
# /kaggle/input/train/F0285/MID6/P12272_face3.jpg
# /kaggle/input/train/F0285/MID1/P12269_face2.jpg
# /kaggle/input/train/F0285/MID1/P12274_face1.jpg
# /kaggle/input/train/F0285/MID1/P12270_face2.jpg
# /kaggle/input/train/F0285/MID1/P12265_face3.jpg
# /kaggle/input/train/F0285/MID1/P12264_face5.jpg
# /kaggle/input/train/F0285/MID1/P12273_face3.jpg
# /kaggle/input/train/F0285/MID1/P12268_face1.jpg
# /kaggle/input/train/F0285/MID1/P12275_face1.jpg
# /kaggle/input/train/F0285/MID1/P12276_face1.jpg
# /kaggle/input/train/F0285/MID1/P12263_face1.jpg
# /kaggle/input/train/F0285/MID3/P12264_face2.jpg
# /kaggle/input/train/F0285/MID3/P12267_face1.jpg
# /kaggle/input/train/F0285/MID3/P12270_face1.jpg
# /kaggle/input/train/F0285/MID4/P12268_face2.jpg
# /kaggle/input/train/F0285/MID4/P12272_face2.jpg
# /kaggle/input/train/F0285/MID4/P12264_face3.jpg
# /kaggle/input/train/F0285/MID5/P12264_face1.jpg
# /kaggle/input/train/F0285/MID5/P12273_face1.jpg
# /kaggle/input/train/F0285/MID2/P12263_face2.jpg
# /kaggle/input/train/F0285/MID2/P12264_face6.jpg
# /kaggle/input/train/F0285/MID2/P12269_face1.jpg
# /kaggle/input/train/F0285/MID2/P12267_face2.jpg
# /kaggle/input/train/F0285/MID2/P12272_face4.jpg
# /kaggle/input/train/F0285/MID2/P12271_face1.jpg
# /kaggle/input/train/F0285/MID2/P12266_face1.jpg
# /kaggle/input/train/F0285/MID2/P12265_face2.jpg
# /kaggle/input/train/F0752/MID10/P07887_face2.jpg
# /kaggle/input/train/F0752/MID7/P07879_face5.jpg
# /kaggle/input/train/F0752/MID7/P07904_face4.jpg
# /kaggle/input/train/F0752/MID6/P07904_face3.jpg
# /kaggle/input/train/F0752/MID6/P07879_face3.jpg
# /kaggle/input/train/F0752/MID9/P07879_face2.jpg
# /kaggle/input/train/F0752/MID9/P07904_face2.jpg
# /kaggle/input/train/F0752/MID1/P07886_face2.jpg
# /kaggle/input/train/F0752/MID1/P07896_face4.jpg
# /kaggle/input/train/F0752/MID1/P07897_face4.jpg
# /kaggle/input/train/F0752/MID1/P07899_face3.jpg
# /kaggle/input/train/F0752/MID1/P07884_face3.jpg
# /kaggle/input/train/F0752/MID1/P07892_face4.jpg
# /kaggle/input/train/F0752/MID1/P07908_face2.jpg
# /kaggle/input/train/F0752/MID1/P07891_face4.jpg
# /kaggle/input/train/F0752/MID1/P07905_face3.jpg
# /kaggle/input/train/F0752/MID1/P07878_face10.jpg
# /kaggle/input/train/F0752/MID1/P07902_face3.jpg
# /kaggle/input/train/F0752/MID1/P07895_face3.jpg
# /kaggle/input/train/F0752/MID1/P07880_face4.jpg
# /kaggle/input/train/F0752/MID1/P07885_face2.jpg
# /kaggle/input/train/F0752/MID1/P07901_face4.jpg
# /kaggle/input/train/F0752/MID1/P07909_face4.jpg
# /kaggle/input/train/F0752/MID1/P07893_face4.jpg
# /kaggle/input/train/F0752/MID1/P07883_face2.jpg
# /kaggle/input/train/F0752/MID3/P07895_face2.jpg
# /kaggle/input/train/F0752/MID3/P07902_face1.jpg
# /kaggle/input/train/F0752/MID3/P07887_face1.jpg
# /kaggle/input/train/F0752/MID3/P07909_face1.jpg
# /kaggle/input/train/F0752/MID3/P07905_face2.jpg
# /kaggle/input/train/F0752/MID3/P07883_face3.jpg
# /kaggle/input/train/F0752/MID3/P07878_face7.jpg
# /kaggle/input/train/F0752/MID3/P07886_face1.jpg
# /kaggle/input/train/F0752/MID3/P07907_face3.jpg
# /kaggle/input/train/F0752/MID3/P07884_face1.jpg
# /kaggle/input/train/F0752/MID3/P07893_face1.jpg
# /kaggle/input/train/F0752/MID3/P07894_face6.jpg
# /kaggle/input/train/F0752/MID3/P07896_face3.jpg
# /kaggle/input/train/F0752/MID3/P07880_face1.jpg
# /kaggle/input/train/F0752/MID3/P07900_face2.jpg
# /kaggle/input/train/F0752/MID3/P07897_face1.jpg
# /kaggle/input/train/F0752/MID3/P07901_face2.jpg
# /kaggle/input/train/F0752/MID3/P07891_face3.jpg
# /kaggle/input/train/F0752/MID3/P07892_face1.jpg
# /kaggle/input/train/F0752/MID4/P07899_face2.jpg
# /kaggle/input/train/F0752/MID4/P07880_face3.jpg
# /kaggle/input/train/F0752/MID4/P07896_face1.jpg
# /kaggle/input/train/F0752/MID4/P07909_face2.jpg
# /kaggle/input/train/F0752/MID4/P07895_face4.jpg
# /kaggle/input/train/F0752/MID4/P07878_face2.jpg
# /kaggle/input/train/F0752/MID4/P07891_face1.jpg
# /kaggle/input/train/F0752/MID4/P07892_face2.jpg
# /kaggle/input/train/F0752/MID4/P07901_face3.jpg
# /kaggle/input/train/F0752/MID4/P07897_face3.jpg
# /kaggle/input/train/F0752/MID4/P07890_face1.jpg
# /kaggle/input/train/F0752/MID4/P07898_face2.jpg
# /kaggle/input/train/F0752/MID4/P07900_face1.jpg
# /kaggle/input/train/F0752/MID4/P07907_face1.jpg
# /kaggle/input/train/F0752/MID4/P07888_face2.jpg
# /kaggle/input/train/F0752/MID4/P07893_face3.jpg
# /kaggle/input/train/F0752/MID4/P07894_face4.jpg
# /kaggle/input/train/F0752/MID5/P07878_face3.jpg
# /kaggle/input/train/F0752/MID2/P07896_face2.jpg
# /kaggle/input/train/F0752/MID2/P07879_face1.jpg
# /kaggle/input/train/F0752/MID2/P07908_face1.jpg
# /kaggle/input/train/F0752/MID2/P07901_face1.jpg
# /kaggle/input/train/F0752/MID2/P07904_face1.jpg
# /kaggle/input/train/F0752/MID2/P07897_face2.jpg
# /kaggle/input/train/F0752/MID2/P07894_face1.jpg
# /kaggle/input/train/F0752/MID2/P07893_face2.jpg
# /kaggle/input/train/F0752/MID2/P07899_face1.jpg
# /kaggle/input/train/F0752/MID2/P07909_face3.jpg
# /kaggle/input/train/F0752/MID2/P07898_face1.jpg
# /kaggle/input/train/F0752/MID2/P07892_face3.jpg
# /kaggle/input/train/F0752/MID2/P07889_face1.jpg
# /kaggle/input/train/F0752/MID2/P07883_face5.jpg
# /kaggle/input/train/F0752/MID2/P07895_face1.jpg
# /kaggle/input/train/F0752/MID2/P07900_face3.jpg
# /kaggle/input/train/F0752/MID2/P07905_face1.jpg
# /kaggle/input/train/F0752/MID2/P07878_face6.jpg
# /kaggle/input/train/F0752/MID2/P07891_face2.jpg
# /kaggle/input/train/F0752/MID2/P07880_face2.jpg
# /kaggle/input/train/F0752/MID2/P07907_face2.jpg
# /kaggle/input/train/F0752/MID8/P07879_face4.jpg
# /kaggle/input/train/F0947/MID1/P09982_face2.jpg
# /kaggle/input/train/F0947/MID1/P09980_face1.jpg
# /kaggle/input/train/F0947/MID1/P09979_face2.jpg
# /kaggle/input/train/F0947/MID1/P09981_face1.jpg
# /kaggle/input/train/F0947/MID1/P09984_face3.jpg
# /kaggle/input/train/F0947/MID3/P09978_face1.jpg
# /kaggle/input/train/F0947/MID3/P09981_face2.jpg
# /kaggle/input/train/F0947/MID3/P09979_face3.jpg
# /kaggle/input/train/F0947/MID3/P09982_face1.jpg
# /kaggle/input/train/F0947/MID3/P09984_face2.jpg
# /kaggle/input/train/F0947/MID3/P09977_face1.jpg
# /kaggle/input/train/F0947/MID3/P09980_face2.jpg
# /kaggle/input/train/F0947/MID2/P09979_face1.jpg
# /kaggle/input/train/F0947/MID2/P09981_face3.jpg
# /kaggle/input/train/F0947/MID2/P09982_face3.jpg
# /kaggle/input/train/F0947/MID2/P09976_face1.jpg
# /kaggle/input/train/F0947/MID2/P09984_face1.jpg
# /kaggle/input/train/F0947/MID2/P09978_face2.jpg
# /kaggle/input/train/F0411/MID1/P04330_face2.jpg
# /kaggle/input/train/F0411/MID1/P04326_face2.jpg
# /kaggle/input/train/F0411/MID3/P04325_face2.jpg
# /kaggle/input/train/F0411/MID3/P04327_face2.jpg
# /kaggle/input/train/F0411/MID3/P04328_face2.jpg
# /kaggle/input/train/F0411/MID3/P04329_face2.jpg
# /kaggle/input/train/F0411/MID2/P04326_face1.jpg
# /kaggle/input/train/F0411/MID2/P04327_face1.jpg
# /kaggle/input/train/F0411/MID2/P04325_face1.jpg
# /kaggle/input/train/F0411/MID2/P04330_face1.jpg
# /kaggle/input/train/F0411/MID2/P04329_face1.jpg
# /kaggle/input/train/F0411/MID2/P04328_face1.jpg
# /kaggle/input/train/F0283/MID1/P03018_face4.jpg
# /kaggle/input/train/F0283/MID1/P03024_face5.jpg
# /kaggle/input/train/F0283/MID1/P03020_face1.jpg
# /kaggle/input/train/F0283/MID1/P03025_face1.jpg
# /kaggle/input/train/F0283/MID1/P03026_face1.jpg
# /kaggle/input/train/F0283/MID1/P03022_face1.jpg
# /kaggle/input/train/F0283/MID1/P03028_face1.jpg
# /kaggle/input/train/F0283/MID1/P03019_face1.jpg
# /kaggle/input/train/F0283/MID1/P03021_face1.jpg
# /kaggle/input/train/F0283/MID3/P03024_face2.jpg
# /kaggle/input/train/F0283/MID3/P03020_face4.jpg
# /kaggle/input/train/F0283/MID3/P03018_face3.jpg
# /kaggle/input/train/F0283/MID4/P03026_face3.jpg
# /kaggle/input/train/F0283/MID4/P03028_face2.jpg
# /kaggle/input/train/F0283/MID4/P03019_face2.jpg
# /kaggle/input/train/F0283/MID4/P03018_face2.jpg
# /kaggle/input/train/F0283/MID4/P03024_face3.jpg
# /kaggle/input/train/F0283/MID5/P03019_face3.jpg
# /kaggle/input/train/F0283/MID5/P03018_face1.jpg
# /kaggle/input/train/F0283/MID5/P03023_face1.jpg
# /kaggle/input/train/F0283/MID5/P03026_face2.jpg
# /kaggle/input/train/F0283/MID2/P03018_face5.jpg
# /kaggle/input/train/F0283/MID2/P03021_face2.jpg
# /kaggle/input/train/F0283/MID2/P03020_face11.jpg
# /kaggle/input/train/F0283/MID2/P03022_face2.jpg
# /kaggle/input/train/F0077/MID6/P00789_face2.jpg
# /kaggle/input/train/F0077/MID6/P00787_face1.jpg
# /kaggle/input/train/F0077/MID6/P00786_face1.jpg
# /kaggle/input/train/F0077/MID1/P00786_face3.jpg
# /kaggle/input/train/F0077/MID1/P00794_face2.jpg
# /kaggle/input/train/F0077/MID1/P00790_face3.jpg
# /kaggle/input/train/F0077/MID1/P00783_face3.jpg
# /kaggle/input/train/F0077/MID1/P00791_face3.jpg
# /kaggle/input/train/F0077/MID1/P00787_face2.jpg
# /kaggle/input/train/F0077/MID1/P00789_face3.jpg
# /kaggle/input/train/F0077/MID1/P00793_face2.jpg
# /kaggle/input/train/F0077/MID1/P00785_face2.jpg
# /kaggle/input/train/F0077/MID1/P00784_face4.jpg
# /kaggle/input/train/F0077/MID3/P00790_face1.jpg
# /kaggle/input/train/F0077/MID3/P00794_face1.jpg
# /kaggle/input/train/F0077/MID3/P00783_face1.jpg
# /kaggle/input/train/F0077/MID3/P00791_face1.jpg
# /kaggle/input/train/F0077/MID3/P00793_face1.jpg
# /kaggle/input/train/F0077/MID3/P00792_face3.jpg
# /kaggle/input/train/F0077/MID3/P00785_face1.jpg
# /kaggle/input/train/F0077/MID4/P00784_face1.jpg
# /kaggle/input/train/F0077/MID2/P00783_face4.jpg
# /kaggle/input/train/F0077/MID2/P00784_face3.jpg
# /kaggle/input/train/F0077/MID2/P00792_face2.jpg
# /kaggle/input/train/F0413/MID6/P11228_face1.jpg
# /kaggle/input/train/F0413/MID1/P11230_face2.jpg
# /kaggle/input/train/F0413/MID1/P11229_face2.jpg
# /kaggle/input/train/F0413/MID1/P11226_face1.jpg
# /kaggle/input/train/F0413/MID1/P04343_face1.jpg
# /kaggle/input/train/F0413/MID1/P04342_face2.jpg
# /kaggle/input/train/F0413/MID1/P11227_face1.jpg
# /kaggle/input/train/F0413/MID3/P04343_face2.jpg
# /kaggle/input/train/F0413/MID5/P11226_face2.jpg
# /kaggle/input/train/F0413/MID5/P11227_face2.jpg
# /kaggle/input/train/F0413/MID5/P11229_face1.jpg
# /kaggle/input/train/F0413/MID5/P11230_face1.jpg
# /kaggle/input/train/F0413/MID2/P04342_face1.jpg
# /kaggle/input/train/F0179/MID1/P11264_face1.jpg
# /kaggle/input/train/F0179/MID1/P11262_face3.jpg
# /kaggle/input/train/F0179/MID1/P11266_face2.jpg
# /kaggle/input/train/F0179/MID1/P01921_face1.jpg
# /kaggle/input/train/F0179/MID1/P11261_face2.jpg
# /kaggle/input/train/F0179/MID1/P11263_face2.jpg
# /kaggle/input/train/F0179/MID1/P11259_face1.jpg
# /kaggle/input/train/F0179/MID1/P11260_face2.jpg
# /kaggle/input/train/F0179/MID3/P11262_face2.jpg
# /kaggle/input/train/F0179/MID3/P11260_face1.jpg
# /kaggle/input/train/F0179/MID3/P11265_face1.jpg
# /kaggle/input/train/F0179/MID3/P11261_face4.jpg
# /kaggle/input/train/F0179/MID3/P11264_face2.jpg
# /kaggle/input/train/F0179/MID3/P01922_face3.jpg
# /kaggle/input/train/F0179/MID4/P11261_face3.jpg
# /kaggle/input/train/F0179/MID2/P11266_face1.jpg
# /kaggle/input/train/F0179/MID2/P11261_face1.jpg
# /kaggle/input/train/F0179/MID2/P01921_face2.jpg
# /kaggle/input/train/F0179/MID2/P11262_face1.jpg
# /kaggle/input/train/F0179/MID2/P11263_face1.jpg
# /kaggle/input/train/F0179/MID2/P11259_face2.jpg
# /kaggle/input/train/F0440/MID1/P04644_face2.jpg
# /kaggle/input/train/F0440/MID1/P04642_face2.jpg
# /kaggle/input/train/F0440/MID1/P04639_face2.jpg
# /kaggle/input/train/F0440/MID1/P04641_face2.jpg
# /kaggle/input/train/F0440/MID1/P04640_face2.jpg
# /kaggle/input/train/F0440/MID1/P04643_face1.jpg
# /kaggle/input/train/F0440/MID1/P04645_face2.jpg
# /kaggle/input/train/F0440/MID3/P04640_face3.jpg
# /kaggle/input/train/F0440/MID3/P04641_face4.jpg
# /kaggle/input/train/F0440/MID4/P04641_face3.jpg
# /kaggle/input/train/F0440/MID4/P04640_face4.jpg
# /kaggle/input/train/F0440/MID2/P04644_face1.jpg
# /kaggle/input/train/F0440/MID2/P04645_face1.jpg
# /kaggle/input/train/F0440/MID2/P04643_face2.jpg
# /kaggle/input/train/F0440/MID2/P04640_face1.jpg
# /kaggle/input/train/F0440/MID2/P04639_face1.jpg
# /kaggle/input/train/F0440/MID2/P04642_face1.jpg
# /kaggle/input/train/F0440/MID2/P04641_face1.jpg
# /kaggle/input/train/F0981/MID1/P10335_face2.jpg
# /kaggle/input/train/F0981/MID1/P10333_face1.jpg
# /kaggle/input/train/F0981/MID1/P10340_face3.jpg
# /kaggle/input/train/F0981/MID1/P10334_face2.jpg
# /kaggle/input/train/F0981/MID1/P10338_face1.jpg
# /kaggle/input/train/F0981/MID1/P10342_face2.jpg
# /kaggle/input/train/F0981/MID1/P10336_face1.jpg
# /kaggle/input/train/F0981/MID1/P10341_face3.jpg
# /kaggle/input/train/F0981/MID1/P10337_face1.jpg
# /kaggle/input/train/F0981/MID3/P10338_face3.jpg
# /kaggle/input/train/F0981/MID3/P10340_face2.jpg
# /kaggle/input/train/F0981/MID3/P10339_face1.jpg
# /kaggle/input/train/F0981/MID4/P10339_face2.jpg
# /kaggle/input/train/F0981/MID5/P10341_face1.jpg
# /kaggle/input/train/F0981/MID5/P10339_face3.jpg
# /kaggle/input/train/F0981/MID5/P10338_face2.jpg
# /kaggle/input/train/F0981/MID5/P10340_face1.jpg
# /kaggle/input/train/F0981/MID2/P10335_face1.jpg
# /kaggle/input/train/F0981/MID2/P10334_face1.jpg
# /kaggle/input/train/F0981/MID2/P10336_face2.jpg
# /kaggle/input/train/F0981/MID2/P10341_face2.jpg
# /kaggle/input/train/F0981/MID2/P10342_face1.jpg
# /kaggle/input/train/F0981/MID2/P10337_face3.jpg
# /kaggle/input/train/F0981/MID2/P10333_face2.jpg
# /kaggle/input/train/F0809/MID1/P08563_face1.jpg
# /kaggle/input/train/F0809/MID1/P08558_face1.jpg
# /kaggle/input/train/F0809/MID1/P08564_face2.jpg
# /kaggle/input/train/F0809/MID1/P08560_face1.jpg
# /kaggle/input/train/F0809/MID1/P08562_face1.jpg
# /kaggle/input/train/F0809/MID1/P08557_face2.jpg
# /kaggle/input/train/F0809/MID1/P08559_face1.jpg
# /kaggle/input/train/F0809/MID3/P08557_face3.jpg
# /kaggle/input/train/F0809/MID3/P08563_face6.jpg
# /kaggle/input/train/F0809/MID5/P08563_face2.jpg
# /kaggle/input/train/F0809/MID5/P08560_face2.jpg
# /kaggle/input/train/F0809/MID2/P08563_face3.jpg
# /kaggle/input/train/F0809/MID2/P08558_face2.jpg
# /kaggle/input/train/F0809/MID2/P08557_face1.jpg
# /kaggle/input/train/F0543/MID1/P05700_face2.jpg
# /kaggle/input/train/F0543/MID1/P05697_face1.jpg
# /kaggle/input/train/F0543/MID1/P05696_face2.jpg
# /kaggle/input/train/F0543/MID1/P05701_face1.jpg
# /kaggle/input/train/F0543/MID3/P05702_face1.jpg
# /kaggle/input/train/F0543/MID3/P05704_face1.jpg
# /kaggle/input/train/F0543/MID4/P05696_face1.jpg
# /kaggle/input/train/F0543/MID5/P05700_face1.jpg
# /kaggle/input/train/F0543/MID2/P05702_face2.jpg
# /kaggle/input/train/F0543/MID2/P05705_face1.jpg
# /kaggle/input/train/F0491/MID1/P05169_face1.jpg
# /kaggle/input/train/F0491/MID1/P05175_face1.jpg
# /kaggle/input/train/F0491/MID1/P05176_face2.jpg
# /kaggle/input/train/F0491/MID1/P05171_face1.jpg
# /kaggle/input/train/F0491/MID1/P05170_face1.jpg
# /kaggle/input/train/F0491/MID1/P05172_face2.jpg
# /kaggle/input/train/F0491/MID3/P05175_face2.jpg
# /kaggle/input/train/F0491/MID3/P05174_face1.jpg
# /kaggle/input/train/F0491/MID3/P05173_face1.jpg
# /kaggle/input/train/F0491/MID4/P05178_face2.jpg
# /kaggle/input/train/F0491/MID2/P05171_face2.jpg
# /kaggle/input/train/F0491/MID2/P05176_face1.jpg
# /kaggle/input/train/F0491/MID2/P05170_face2.jpg
# /kaggle/input/train/F0491/MID2/P05178_face1.jpg
# /kaggle/input/train/F0491/MID2/P05169_face2.jpg
# /kaggle/input/train/F0491/MID2/P05172_face1.jpg
# /kaggle/input/train/F0254/MID1/P02693_face2.jpg
# /kaggle/input/train/F0254/MID1/P02697_face1.jpg
# /kaggle/input/train/F0254/MID1/P02691_face3.jpg
# /kaggle/input/train/F0254/MID1/P02694_face1.jpg
# /kaggle/input/train/F0254/MID1/P02695_face1.jpg
# /kaggle/input/train/F0254/MID1/P02696_face2.jpg
# /kaggle/input/train/F0254/MID1/P02690_face4.jpg
# /kaggle/input/train/F0254/MID1/P02699_face1.jpg
# /kaggle/input/train/F0254/MID1/P02692_face2.jpg
# /kaggle/input/train/F0254/MID3/P02690_face3.jpg
# /kaggle/input/train/F0254/MID4/P02692_face1.jpg
# /kaggle/input/train/F0254/MID4/P02693_face1.jpg

# %%
from collections import defaultdict
from glob import glob
from random import choice, sample

import cv2
import numpy as np
import pandas as pd
from keras.applications.resnet50 import ResNet50, preprocess_input
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.layers import Input, Dense, GlobalMaxPool2D, GlobalAvgPool2D, Concatenate, Multiply, Dropout, Subtract
from keras.models import Model
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.

# %%
train_file_path = "../input/train_relationships.csv"  # training file which gives us kinship relationship in the training dataset
train_folders_path = "/kaggle/input/train/" # training dataset  
val_famillies = "F09" # vlidation data, we will use it while training the model

# %%
all_images = glob(train_folders_path + "*/*/*.jpg")  # get all images in training set

train_images = [x for x in all_images if val_famillies not in x] # training images 
val_images = [x for x in all_images if val_famillies in x] # validatoin images

ppl = [x.split("/")[-3] + "/" + x.split("/")[-2] for x in all_images] # all persons in training set

# %%
# mapping pictures into training and validation set
train_person_to_images_map = defaultdict(list)  
for x in train_images:
    train_person_to_images_map[x.split("/")[-3] + "/" + x.split("/")[-2]].append(x)

val_person_to_images_map = defaultdict(list)

for x in val_images:
    val_person_to_images_map[x.split("/")[-3] + "/" + x.split("/")[-2]].append(x)

# %%
# transform training labels into variables so that we can use it suring training
relationships = pd.read_csv(train_file_path)
relationships = list(zip(relationships.p1.values, relationships.p2.values))
relationships = [x for x in relationships if x[0] in ppl and x[1] in ppl]

# %%
# get training sets and validation sets
train = [x for x in relationships if val_famillies not in x[0]]
val = [x for x in relationships if val_famillies in x[0]]

# %%
# function to read images
def read_img(path):
    img = cv2.imread(path)
    return preprocess_input(img)

# %%
# generate input pairs
def gen(list_tuples, person_to_images_map, batch_size=16):
    ppl = list(person_to_images_map.keys())
    while True:
        batch_tuples = sample(list_tuples, batch_size // 2) # choose batch_size/2 pairs of relationships randomly from training set(having relaionship),which outputs 1
        labels = [1] * len(batch_tuples)
        while len(batch_tuples) < batch_size: # choose batch_size/2 pairs of relationships randomly(not having relationships), which outputs 0
            p1 = choice(ppl)
            p2 = choice(ppl)

            if p1 != p2 and (p1, p2) not in list_tuples and (p2, p1) not in list_tuples: 
                batch_tuples.append((p1, p2))
                labels.append(0)

        for x in batch_tuples: # if it's null, print it
            if not len(person_to_images_map[x[0]]):
                print(x[0])

        # generate input pairs with labels, which we will use in model.fit_generator()
        X1 = [choice(person_to_images_map[x[0]]) for x in batch_tuples]
        X1 = np.array([read_img(x) for x in X1])

        X2 = [choice(person_to_images_map[x[1]]) for x in batch_tuples]
        X2 = np.array([read_img(x) for x in X2])

        yield [X1, X2], labels

# %%
# structure of siamese network 
def baseline_model():
    input_1 = Input(shape=(224, 224, 3))
    input_2 = Input(shape=(224, 224, 3))

    base_model = ResNet50(weights='imagenet', include_top=False)

    for x in base_model.layers[:]:
        x.trainable = True

    x1 = base_model(input_1)
    x2 = base_model(input_2) # here is two RestNet 50 deep learning model

    x1 = Concatenate(axis=-1)([GlobalMaxPool2D()(x1), GlobalAvgPool2D()(x1)])
    x2 = Concatenate(axis=-1)([GlobalMaxPool2D()(x2), GlobalAvgPool2D()(x2)])

    x3 = Subtract()([x1, x2])
    x3 = Multiply()([x3, x3])

    x = Multiply()([x1, x2]) # x is distance difference

    x = Concatenate(axis=-1)([x, x3])

    # here is the third deep learning model, input is distance difference, output is 0/1
    x = Dense(100, activation="relu")(x)
    x = Dropout(0.01)(x)
    out = Dense(1, activation="sigmoid")(x)

    model = Model([input_1, input_2], out)

    model.compile(loss="binary_crossentropy", metrics=['acc'], optimizer=Adam(0.00001))

    model.summary()

    return model

# %%
# Transfer learning here, baseline.h5 is the ResNet50 weights download from Internet.
file_path = "baseline.h5"

checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

reduce_on_plateau = ReduceLROnPlateau(monitor="val_acc", mode="max", factor=0.1, patience=20, verbose=1)

callbacks_list = [checkpoint, reduce_on_plateau]

model = baseline_model()
# start to train the whole model
model.fit_generator(gen(train, train_person_to_images_map, batch_size=16), use_multiprocessing=True,
                    validation_data=gen(val, val_person_to_images_map, batch_size=16), epochs=100, verbose=2,
                    workers=4, callbacks=callbacks_list, steps_per_epoch=200, validation_steps=100)

test_path = "/kaggle/input/test/"
# Out:
# /opt/conda/lib/python3.6/site-packages/keras_applications/resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94658560/94653016 [==============================] - 1s 0us/step
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# resnet50 (Model)                multiple             23587712    input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_1 (GlobalM (None, 2048)         0           resnet50[1][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 2048)         0           resnet50[1][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_2 (GlobalM (None, 2048)         0           resnet50[2][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 2048)         0           resnet50[2][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4096)         0           global_max_pooling2d_1[0][0]
#                                                                  global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 4096)         0           global_max_pooling2d_2[0][0]
#                                                                  global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# subtract_1 (Subtract)           (None, 4096)         0           concatenate_1[0][0]
#                                                                  concatenate_2[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 4096)         0           concatenate_1[0][0]
#                                                                  concatenate_2[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 4096)         0           subtract_1[0][0]
#                                                                  subtract_1[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 8192)         0           multiply_2[0][0]
#                                                                  multiply_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100)          819300      concatenate_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 100)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            101         dropout_1[0][0]
# ==================================================================================================
# Total params: 24,407,113
# Trainable params: 24,353,993
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
# Epoch 1/100
# /opt/conda/lib/python3.6/site-packages/keras/engine/training_generator.py:49: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
#  - 143s - loss: 12.4057 - acc: 0.4956 - val_loss: 9.9277 - val_acc: 0.5206
#
# Epoch 00001: val_acc improved from -inf to 0.52062, saving model to baseline.h5
# Epoch 2/100
#  - 92s - loss: 7.3968 - acc: 0.5362 - val_loss: 7.4468 - val_acc: 0.5231
#
# Epoch 00002: val_acc improved from 0.52062 to 0.52312, saving model to baseline.h5
# Epoch 3/100
#  - 92s - loss: 5.2469 - acc: 0.5509 - val_loss: 4.7993 - val_acc: 0.5200
#
# Epoch 00003: val_acc did not improve from 0.52312
# Epoch 4/100
#  - 93s - loss: 3.6917 - acc: 0.5562 - val_loss: 2.6100 - val_acc: 0.5406
#
# Epoch 00004: val_acc improved from 0.52312 to 0.54062, saving model to baseline.h5
# Epoch 5/100
#  - 92s - loss: 2.6764 - acc: 0.5616 - val_loss: 3.5156 - val_acc: 0.5394
#
# Epoch 00005: val_acc did not improve from 0.54062
# Epoch 6/100
#  - 93s - loss: 1.9144 - acc: 0.5656 - val_loss: 1.4335 - val_acc: 0.5356
#
# Epoch 00006: val_acc did not improve from 0.54062
# Epoch 7/100
#  - 92s - loss: 1.5187 - acc: 0.5644 - val_loss: 0.8385 - val_acc: 0.5475
#
# Epoch 00007: val_acc improved from 0.54062 to 0.54750, saving model to baseline.h5
# Epoch 8/100
#  - 93s - loss: 1.2057 - acc: 0.5669 - val_loss: 1.5457 - val_acc: 0.5244
#
# Epoch 00008: val_acc did not improve from 0.54750
# Epoch 9/100
#  - 92s - loss: 0.9979 - acc: 0.5578 - val_loss: 1.0195 - val_acc: 0.5487
#
# Epoch 00009: val_acc improved from 0.54750 to 0.54875, saving model to baseline.h5
# Epoch 10/100
#  - 92s - loss: 0.9003 - acc: 0.5650 - val_loss: 1.2589 - val_acc: 0.5325
#
# Epoch 00010: val_acc did not improve from 0.54875
# Epoch 11/100
#  - 92s - loss: 0.8402 - acc: 0.5562 - val_loss: 0.7288 - val_acc: 0.5263
#
# Epoch 00011: val_acc did not improve from 0.54875
# Epoch 12/100
#  - 92s - loss: 0.7654 - acc: 0.5759 - val_loss: 0.6248 - val_acc: 0.5487
#
# Epoch 00012: val_acc did not improve from 0.54875
# Epoch 13/100
#  - 92s - loss: 0.7648 - acc: 0.5566 - val_loss: 0.7014 - val_acc: 0.5594
#
# Epoch 00013: val_acc improved from 0.54875 to 0.55937, saving model to baseline.h5
# Epoch 14/100
#  - 92s - loss: 0.7564 - acc: 0.5506 - val_loss: 0.6281 - val_acc: 0.5581
#
# Epoch 00014: val_acc did not improve from 0.55937
# Epoch 15/100
#  - 92s - loss: 0.7267 - acc: 0.5434 - val_loss: 0.8253 - val_acc: 0.5763
#
# Epoch 00015: val_acc improved from 0.55937 to 0.57625, saving model to baseline.h5
# Epoch 16/100
#  - 92s - loss: 0.7108 - acc: 0.5678 - val_loss: 0.4876 - val_acc: 0.5569
#
# Epoch 00016: val_acc did not improve from 0.57625
# Epoch 17/100
#  - 93s - loss: 0.7267 - acc: 0.5437 - val_loss: 1.4405 - val_acc: 0.5600
#
# Epoch 00017: val_acc did not improve from 0.57625
# Epoch 18/100
#  - 92s - loss: 0.7000 - acc: 0.5806 - val_loss: 0.7384 - val_acc: 0.5569
#
# Epoch 00018: val_acc did not improve from 0.57625
# Epoch 19/100
#  - 93s - loss: 0.7001 - acc: 0.5641 - val_loss: 0.6741 - val_acc: 0.5594
#
# Epoch 00019: val_acc did not improve from 0.57625
# Epoch 20/100
#  - 92s - loss: 0.6813 - acc: 0.5728 - val_loss: 0.7095 - val_acc: 0.5944
#
# Epoch 00020: val_acc improved from 0.57625 to 0.59438, saving model to baseline.h5
# Epoch 21/100
#  - 92s - loss: 0.6861 - acc: 0.5847 - val_loss: 0.6293 - val_acc: 0.5469
#
# Epoch 00021: val_acc did not improve from 0.59438
# Epoch 22/100
#  - 92s - loss: 0.6687 - acc: 0.5956 - val_loss: 0.7917 - val_acc: 0.5881
#
# Epoch 00022: val_acc did not improve from 0.59438
# Epoch 23/100
#  - 92s - loss: 0.6701 - acc: 0.5903 - val_loss: 0.7744 - val_acc: 0.5800
#
# Epoch 00023: val_acc did not improve from 0.59438
# Epoch 24/100
#  - 92s - loss: 0.6767 - acc: 0.5997 - val_loss: 0.6992 - val_acc: 0.5925
#
# Epoch 00024: val_acc did not improve from 0.59438
# Epoch 25/100
#  - 93s - loss: 0.6626 - acc: 0.6000 - val_loss: 0.7163 - val_acc: 0.5950
#
# Epoch 00025: val_acc improved from 0.59438 to 0.59500, saving model to baseline.h5
# Epoch 26/100
#  - 93s - loss: 0.6615 - acc: 0.5944 - val_loss: 0.5753 - val_acc: 0.5994
#
# Epoch 00026: val_acc improved from 0.59500 to 0.59938, saving model to baseline.h5
# Epoch 27/100
#  - 92s - loss: 0.6440 - acc: 0.6194 - val_loss: 0.7042 - val_acc: 0.5900
#
# Epoch 00027: val_acc did not improve from 0.59938
# Epoch 28/100
#  - 93s - loss: 0.6489 - acc: 0.6000 - val_loss: 0.7248 - val_acc: 0.5856
#
# Epoch 00028: val_acc did not improve from 0.59938
# Epoch 29/100
#  - 92s - loss: 0.6511 - acc: 0.6231 - val_loss: 0.6017 - val_acc: 0.5913
#
# Epoch 00029: val_acc did not improve from 0.59938
# Epoch 30/100
#  - 92s - loss: 0.6356 - acc: 0.6350 - val_loss: 0.8014 - val_acc: 0.6056
#
# Epoch 00030: val_acc improved from 0.59938 to 0.60562, saving model to baseline.h5
# Epoch 31/100
#  - 92s - loss: 0.6439 - acc: 0.6253 - val_loss: 0.7033 - val_acc: 0.6069
#
# Epoch 00031: val_acc improved from 0.60562 to 0.60688, saving model to baseline.h5
# Epoch 32/100
#  - 92s - loss: 0.6381 - acc: 0.6266 - val_loss: 1.1203 - val_acc: 0.5938
#
# Epoch 00032: val_acc did not improve from 0.60688
# Epoch 33/100
#  - 92s - loss: 0.6426 - acc: 0.6237 - val_loss: 0.7404 - val_acc: 0.6000
#
# Epoch 00033: val_acc did not improve from 0.60688
# Epoch 34/100
#  - 92s - loss: 0.6294 - acc: 0.6350 - val_loss: 1.0174 - val_acc: 0.6031
#
# Epoch 00034: val_acc did not improve from 0.60688
# Epoch 35/100
#  - 92s - loss: 0.6436 - acc: 0.6291 - val_loss: 0.7861 - val_acc: 0.6200
#
# Epoch 00035: val_acc improved from 0.60688 to 0.62000, saving model to baseline.h5
# Epoch 36/100
#  - 92s - loss: 0.6222 - acc: 0.6522 - val_loss: 0.6709 - val_acc: 0.6050
#
# Epoch 00036: val_acc did not improve from 0.62000
# Epoch 37/100
#  - 93s - loss: 0.6275 - acc: 0.6403 - val_loss: 0.6641 - val_acc: 0.6219
#
# Epoch 00037: val_acc improved from 0.62000 to 0.62187, saving model to baseline.h5
# Epoch 38/100
#  - 92s - loss: 0.6248 - acc: 0.6444 - val_loss: 0.5810 - val_acc: 0.6094
#
# Epoch 00038: val_acc did not improve from 0.62187
# Epoch 39/100
#  - 92s - loss: 0.6064 - acc: 0.6594 - val_loss: 0.6189 - val_acc: 0.5919
#
# Epoch 00039: val_acc did not improve from 0.62187
# Epoch 40/100
#  - 92s - loss: 0.6058 - acc: 0.6494 - val_loss: 0.8631 - val_acc: 0.6112
#
# Epoch 00040: val_acc did not improve from 0.62187
# Epoch 41/100
#  - 92s - loss: 0.6125 - acc: 0.6444 - val_loss: 0.6013 - val_acc: 0.6044
#
# Epoch 00041: val_acc did not improve from 0.62187
# Epoch 42/100
#  - 92s - loss: 0.6015 - acc: 0.6647 - val_loss: 0.6998 - val_acc: 0.6056
#
# Epoch 00042: val_acc did not improve from 0.62187
# Epoch 43/100
#  - 93s - loss: 0.6088 - acc: 0.6509 - val_loss: 0.5233 - val_acc: 0.6000
#
# Epoch 00043: val_acc did not improve from 0.62187
# Epoch 44/100
#  - 92s - loss: 0.6015 - acc: 0.6644 - val_loss: 0.6670 - val_acc: 0.6012
#
# Epoch 00044: val_acc did not improve from 0.62187
# Epoch 45/100
#  - 93s - loss: 0.5985 - acc: 0.6612 - val_loss: 0.8372 - val_acc: 0.6031
#
# Epoch 00045: val_acc did not improve from 0.62187
# Epoch 46/100
#  - 92s - loss: 0.5797 - acc: 0.6797 - val_loss: 0.6341 - val_acc: 0.6137
#
# Epoch 00046: val_acc did not improve from 0.62187
# Epoch 47/100
#  - 92s - loss: 0.6002 - acc: 0.6606 - val_loss: 0.7866 - val_acc: 0.6125
#
# Epoch 00047: val_acc did not improve from 0.62187
# Epoch 48/100
#  - 92s - loss: 0.5998 - acc: 0.6584 - val_loss: 0.4771 - val_acc: 0.6169
#
# Epoch 00048: val_acc did not improve from 0.62187
# Epoch 49/100
#  - 92s - loss: 0.5796 - acc: 0.6806 - val_loss: 0.6992 - val_acc: 0.6150
#
# Epoch 00049: val_acc did not improve from 0.62187
# Epoch 50/100
#  - 92s - loss: 0.5714 - acc: 0.6841 - val_loss: 0.5172 - val_acc: 0.6237
#
# Epoch 00050: val_acc improved from 0.62187 to 0.62375, saving model to baseline.h5
# Epoch 51/100
#  - 92s - loss: 0.5865 - acc: 0.6837 - val_loss: 0.6594 - val_acc: 0.6375
#
# Epoch 00051: val_acc improved from 0.62375 to 0.63750, saving model to baseline.h5
# Epoch 52/100
#  - 92s - loss: 0.5765 - acc: 0.6816 - val_loss: 0.6167 - val_acc: 0.5981
#
# Epoch 00052: val_acc did not improve from 0.63750
# Epoch 53/100
#  - 92s - loss: 0.5776 - acc: 0.6859 - val_loss: 0.8337 - val_acc: 0.6256
#
# Epoch 00053: val_acc did not improve from 0.63750
# Epoch 54/100
#  - 92s - loss: 0.5671 - acc: 0.6922 - val_loss: 0.7027 - val_acc: 0.6106
#
# Epoch 00054: val_acc did not improve from 0.63750
# Epoch 55/100
#  - 92s - loss: 0.5584 - acc: 0.7113 - val_loss: 0.6529 - val_acc: 0.6025
#
# Epoch 00055: val_acc did not improve from 0.63750
# Epoch 56/100
#  - 92s - loss: 0.5525 - acc: 0.6994 - val_loss: 0.4809 - val_acc: 0.6325
#
# Epoch 00056: val_acc did not improve from 0.63750
# Epoch 57/100
#  - 92s - loss: 0.5524 - acc: 0.7069 - val_loss: 0.6419 - val_acc: 0.6131
#
# Epoch 00057: val_acc did not improve from 0.63750
# Epoch 58/100
#  - 92s - loss: 0.5339 - acc: 0.7194 - val_loss: 0.6818 - val_acc: 0.6294
#
# Epoch 00058: val_acc did not improve from 0.63750
# Epoch 59/100
#  - 92s - loss: 0.5445 - acc: 0.7038 - val_loss: 0.4394 - val_acc: 0.6331
#
# Epoch 00059: val_acc did not improve from 0.63750
# Epoch 60/100
#  - 92s - loss: 0.5363 - acc: 0.7216 - val_loss: 0.5348 - val_acc: 0.6150
#
# Epoch 00060: val_acc did not improve from 0.63750
# Epoch 61/100
#  - 92s - loss: 0.5436 - acc: 0.7166 - val_loss: 0.8111 - val_acc: 0.6294
#
# Epoch 00061: val_acc did not improve from 0.63750
# Epoch 62/100
#  - 92s - loss: 0.5292 - acc: 0.7241 - val_loss: 0.7293 - val_acc: 0.6313
#
# Epoch 00062: val_acc did not improve from 0.63750
# Epoch 63/100
#  - 92s - loss: 0.5266 - acc: 0.7150 - val_loss: 0.6806 - val_acc: 0.6300
#
# Epoch 00063: val_acc did not improve from 0.63750
# Epoch 64/100
#  - 92s - loss: 0.5259 - acc: 0.7312 - val_loss: 0.7540 - val_acc: 0.6331
#
# Epoch 00064: val_acc did not improve from 0.63750
# Epoch 65/100
#  - 92s - loss: 0.5056 - acc: 0.7434 - val_loss: 1.0755 - val_acc: 0.6119
#
# Epoch 00065: val_acc did not improve from 0.63750
# Epoch 66/100
#  - 92s - loss: 0.5147 - acc: 0.7397 - val_loss: 0.6614 - val_acc: 0.6125
#
# Epoch 00066: val_acc did not improve from 0.63750
# Epoch 67/100
#  - 92s - loss: 0.5062 - acc: 0.7316 - val_loss: 0.9059 - val_acc: 0.6263
#
# Epoch 00067: val_acc did not improve from 0.63750
# Epoch 68/100
#  - 92s - loss: 0.5198 - acc: 0.7244 - val_loss: 0.7435 - val_acc: 0.6087
#
# Epoch 00068: val_acc did not improve from 0.63750
# Epoch 69/100
#  - 92s - loss: 0.5049 - acc: 0.7303 - val_loss: 0.5073 - val_acc: 0.6450
#
# Epoch 00069: val_acc improved from 0.63750 to 0.64500, saving model to baseline.h5
# Epoch 70/100
#  - 92s - loss: 0.5021 - acc: 0.7422 - val_loss: 0.4635 - val_acc: 0.6331
#
# Epoch 00070: val_acc did not improve from 0.64500
# Epoch 71/100
#  - 92s - loss: 0.4969 - acc: 0.7497 - val_loss: 0.6945 - val_acc: 0.6612
#
# Epoch 00071: val_acc improved from 0.64500 to 0.66125, saving model to baseline.h5
# Epoch 72/100
#  - 92s - loss: 0.4949 - acc: 0.7481 - val_loss: 0.4717 - val_acc: 0.6256
#
# Epoch 00072: val_acc did not improve from 0.66125
# Epoch 73/100
#  - 92s - loss: 0.4885 - acc: 0.7525 - val_loss: 0.8394 - val_acc: 0.6494
#
# Epoch 00073: val_acc did not improve from 0.66125
# Epoch 74/100
#  - 92s - loss: 0.4817 - acc: 0.7619 - val_loss: 0.4274 - val_acc: 0.6156
#
# Epoch 00074: val_acc did not improve from 0.66125
# Epoch 75/100
#  - 92s - loss: 0.4792 - acc: 0.7466 - val_loss: 0.7909 - val_acc: 0.6062
#
# Epoch 00075: val_acc did not improve from 0.66125
# Epoch 76/100
#  - 92s - loss: 0.4844 - acc: 0.7531 - val_loss: 0.3750 - val_acc: 0.6231
#
# Epoch 00076: val_acc did not improve from 0.66125
# Epoch 77/100
#  - 91s - loss: 0.4929 - acc: 0.7384 - val_loss: 0.6945 - val_acc: 0.6256
#
# Epoch 00077: val_acc did not improve from 0.66125
# Epoch 78/100
#  - 92s - loss: 0.4690 - acc: 0.7700 - val_loss: 0.4603 - val_acc: 0.6338
#
# Epoch 00078: val_acc did not improve from 0.66125
# Epoch 79/100
#  - 92s - loss: 0.4603 - acc: 0.7756 - val_loss: 0.5612 - val_acc: 0.6150
#
# Epoch 00079: val_acc did not improve from 0.66125
# Epoch 80/100
#  - 92s - loss: 0.4787 - acc: 0.7672 - val_loss: 0.7331 - val_acc: 0.6506
#
# Epoch 00080: val_acc did not improve from 0.66125
# Epoch 81/100
#  - 92s - loss: 0.4598 - acc: 0.7725 - val_loss: 0.6852 - val_acc: 0.6419
#
# Epoch 00081: val_acc did not improve from 0.66125
# Epoch 82/100
#  - 92s - loss: 0.4530 - acc: 0.7763 - val_loss: 0.6299 - val_acc: 0.6450
#
# Epoch 00082: val_acc did not improve from 0.66125
# Epoch 83/100
#  - 92s - loss: 0.4671 - acc: 0.7734 - val_loss: 0.5695 - val_acc: 0.6400
#
# Epoch 00083: val_acc did not improve from 0.66125
# Epoch 84/100
#  - 92s - loss: 0.4658 - acc: 0.7725 - val_loss: 0.5958 - val_acc: 0.6456
#
# Epoch 00084: val_acc did not improve from 0.66125
# Epoch 85/100
#  - 92s - loss: 0.4522 - acc: 0.7706 - val_loss: 0.6727 - val_acc: 0.6187
#
# Epoch 00085: val_acc did not improve from 0.66125
# Epoch 86/100
#  - 92s - loss: 0.4490 - acc: 0.7725 - val_loss: 0.6254 - val_acc: 0.6338
#
# Epoch 00086: val_acc did not improve from 0.66125
# Epoch 87/100
#  - 92s - loss: 0.4530 - acc: 0.7719 - val_loss: 0.8341 - val_acc: 0.6625
#
# Epoch 00087: val_acc improved from 0.66125 to 0.66250, saving model to baseline.h5
# Epoch 88/100
#  - 92s - loss: 0.4398 - acc: 0.7919 - val_loss: 0.7639 - val_acc: 0.6481
#
# Epoch 00088: val_acc did not improve from 0.66250
# Epoch 89/100
#  - 92s - loss: 0.4202 - acc: 0.7987 - val_loss: 0.5505 - val_acc: 0.6631
#
# Epoch 00089: val_acc improved from 0.66250 to 0.66312, saving model to baseline.h5
# Epoch 90/100
#  - 92s - loss: 0.4425 - acc: 0.7819 - val_loss: 0.8030 - val_acc: 0.6206
#
# Epoch 00090: val_acc did not improve from 0.66312
# Epoch 91/100
#  - 93s - loss: 0.4178 - acc: 0.7937 - val_loss: 0.6916 - val_acc: 0.6363
#
# Epoch 00091: val_acc did not improve from 0.66312
# Epoch 92/100
#  - 92s - loss: 0.4417 - acc: 0.7812 - val_loss: 0.6786 - val_acc: 0.6237
#
# Epoch 00092: val_acc did not improve from 0.66312
# Epoch 93/100
#  - 92s - loss: 0.4163 - acc: 0.7937 - val_loss: 0.7216 - val_acc: 0.6388
#
# Epoch 00093: val_acc did not improve from 0.66312
# Epoch 94/100
#  - 92s - loss: 0.4296 - acc: 0.7931 - val_loss: 0.6856 - val_acc: 0.6344
#
# Epoch 00094: val_acc did not improve from 0.66312
# Epoch 95/100
#  - 92s - loss: 0.4386 - acc: 0.7875 - val_loss: 0.5819 - val_acc: 0.6438
#
# Epoch 00095: val_acc did not improve from 0.66312
# Epoch 96/100
#  - 92s - loss: 0.4096 - acc: 0.7997 - val_loss: 0.7165 - val_acc: 0.6269
#
# Epoch 00096: val_acc did not improve from 0.66312
# Epoch 97/100
#  - 92s - loss: 0.4175 - acc: 0.8016 - val_loss: 0.6391 - val_acc: 0.6375
#
# Epoch 00097: val_acc did not improve from 0.66312
# Epoch 98/100
#  - 92s - loss: 0.4242 - acc: 0.7944 - val_loss: 0.7383 - val_acc: 0.6350
#
# Epoch 00098: val_acc did not improve from 0.66312
# Epoch 99/100
#  - 92s - loss: 0.4086 - acc: 0.8037 - val_loss: 1.2542 - val_acc: 0.6325
#
# Epoch 00099: val_acc did not improve from 0.66312
# Epoch 100/100
#  - 92s - loss: 0.3898 - acc: 0.8153 - val_loss: 0.7622 - val_acc: 0.6456
#
# Epoch 00100: val_acc did not improve from 0.66312

# %%
# seperate testing datasets
def chunker(seq, size=32):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

# %%
# start to test relationship in sample_submission.csv
from tqdm import tqdm

submission = pd.read_csv('../input/sample_submission.csv')

predictions = []

for batch in tqdm(chunker(submission.img_pair.values)):
    X1 = [x.split("-")[0] for x in batch]
    X1 = np.array([read_img(test_path + x) for x in X1])

    X2 = [x.split("-")[1] for x in batch]
    X2 = np.array([read_img(test_path + x) for x in X2])

    pred = model.predict([X1, X2]).ravel().tolist()
    predictions += pred
# Out:
# 166it [01:13,  2.26it/s]

# %%
# We get the final result baseline.csv. After uploading to the Kaggle, we get the accuracy: 75.2
submission['is_related'] = predictions

submission.to_csv("baseline.csv", index=False)
